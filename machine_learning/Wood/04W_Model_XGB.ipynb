# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder

# %%
data = pd.read_csv('/content/wood.csv')

# %% [markdown]
# Statistical description of the data

# %%
new_data = data.drop(columns=data.columns[0])
new_data.describe()
# Out:
#                VOL      AREA_F     APT_NUM      ST_NUM       KREIS  \
# count   286.000000  286.000000  286.000000  286.000000  286.000000
# mean   1512.891608  148.944056    4.695804    4.576923    7.779720
# std     745.066194   49.875885    2.923909    1.004914    3.102417
# min     226.000000   50.000000    1.000000    1.000000    2.000000
# 25%     864.750000  112.250000    1.000000    4.000000    6.000000
# 50%    1582.000000  165.000000    6.000000    5.000000    9.000000
# 75%    1945.000000  176.000000    6.000000    5.000000   11.000000
# max    3570.000000  274.000000   13.000000    7.000000   12.000000
#
#            ZIPCODE          YOC        WOOD
# count   286.000000   286.000000  286.000000
# mean   8043.580420  1942.559441   19.328671
# std      15.729027    11.558924   17.405187
# min    8002.000000  1906.000000    0.770000
# 25%    8045.000000  1933.000000    6.130000
# 50%    8048.000000  1948.000000   13.770000
# 75%    8052.000000  1950.000000   27.910000
# max    8057.000000  1972.000000   75.240000

# %% [markdown]
# One-hot encode of categorical data

# %%
new_data['KREIS'] = new_data['KREIS'].astype('category')
new_data['ZIPCODE'] = new_data['ZIPCODE'].astype('category')
# One-hot encode the data using pandas get_dummies
new_data = pd.get_dummies(new_data)
print
print(new_data.columns)
print(new_data.shape)
# Out:
# Index(['VOL', 'AREA_F', 'APT_NUM', 'ST_NUM', 'YOC', 'WOOD', 'KREIS_2',
#        'KREIS_3', 'KREIS_4', 'KREIS_6', 'KREIS_7', 'KREIS_8', 'KREIS_9',
#        'KREIS_10', 'KREIS_11', 'KREIS_12', 'ZIPCODE_8002', 'ZIPCODE_8003',
#        'ZIPCODE_8004', 'ZIPCODE_8006', 'ZIPCODE_8008', 'ZIPCODE_8032',
#        'ZIPCODE_8038', 'ZIPCODE_8044', 'ZIPCODE_8045', 'ZIPCODE_8046',
#        'ZIPCODE_8047', 'ZIPCODE_8048', 'ZIPCODE_8049', 'ZIPCODE_8050',
#        'ZIPCODE_8051', 'ZIPCODE_8052', 'ZIPCODE_8053', 'ZIPCODE_8055',
#        'ZIPCODE_8057', 'ROOF_F', 'ROOF_M', 'ROOF_O', 'ROOF_P',
#        'POC_1900 - 1919', 'POC_1919 - 1945', 'POC_1946 - 1960',
#        'POC_1961 - 1970', 'POC_1971 - 1980'],
#       dtype='object')
# (286, 44)

# %%
pip install xgboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xgboost in /usr/local/lib/python3.7/dist-packages (0.90)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.7.3)

# %% [markdown]
# Split data into TEST (T) that I don't touch and train + validation set (TV)

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import xgboost as xgb

# labels as numpy array
Y=np.array(new_data['WOOD'])

#features as numpy array
X_list= new_data.drop(columns='WOOD')
X = np.array(X_list)
headers = X_list.columns
X_TV, X_T, Y_TV, Y_T = train_test_split(X,Y,test_size = 0.15, random_state = 296) #this split, meaning, this random seed, has to be the same for all the models!

print(X_T, Y_T)
# Out:
# [[1811  189    3 ...    0    0    0]
#  [3130  182   10 ...    0    0    0]
#  [ 505   70    1 ...    0    0    0]
#  ...
#  [ 780  112    2 ...    0    1    0]
#  [2000  205    9 ...    1    0    0]
#  [1685  150    6 ...    0    0    0]] [ 7.96 36.46 21.76  8.77 21.42 36.75 60.38  5.7  30.    3.21 51.52 11.34
#   1.3   1.34 41.59  5.12  6.14  2.75  5.7   9.13  6.16 29.59 36.27 19.22
#  29.23 13.52 54.28 67.84 22.89  1.32  4.85 15.15 43.29  5.96 10.   23.17
#  22.8   1.46  7.   22.23 33.4  25.8  16.01]

# %% [markdown]
# Hyperparameter search

# %%
from sklearn.model_selection import RandomizedSearchCV

model_pipe = xgb.XGBRegressor(objective='reg:squarederror')

#Metrics for Evualation:
met_grid= ['r2', 'neg_mean_absolute_error'] #The metric codes from sklearn

# Create the parameter grid based on the results of random search 
params = {
          'max_depth': [13],
        'min_child_weight': [0.1],
        'gamma': [100],
        'learning_rate': [0.2, 0.15],
        'subsample': [0.84, 0.85, 0.86],
        'colsample_bylevel': [0.12,0.13,],
        'colsample_bytree': [0.84, 0.85, 0.86],
        'n_estimators': [1000]
      }

# Instantiate the grid search model
grid_search = RandomizedSearchCV(model_pipe, param_distributions = params, scoring = met_grid, refit = 'r2', n_iter = 100,
                                cv = 10, n_jobs = 1, verbose = 10, return_train_score = True)
# Fit the grid search to the data
grid_search.fit(X_TV, Y_TV)

from google.colab import files

gd_w = pd.DataFrame(grid_search.cv_results_)
gd_w.to_csv('grid_search_w_xgb2.csv', encoding = 'utf-8-sig') 
files.download('grid_search_w_xgb2.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py:296: UserWarning: The total space of parameters 36 is smaller than n_iter=100. Running 36 iterations. For exhaustive searches, use GridSearchCV.
#   UserWarning,
# Fitting 10 folds for each of 36 candidates, totalling 360 fits
# [CV 1/10; 1/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 1/10; 1/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.991, test=-8.972) r2: (train=0.975, test=-0.042) total time=   0.3s
# [CV 2/10; 1/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 2/10; 1/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.881, test=-7.141) r2: (train=0.975, test=0.521) total time=   0.3s
# [CV 3/10; 1/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 3/10; 1/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-2.033, test=-6.263) r2: (train=0.973, test=0.578) total time=   0.3s
# [CV 4/10; 1/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 4/10; 1/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.870, test=-7.740) r2: (train=0.977, test=0.357) total time=   0.3s
# [CV 5/10; 1/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 5/10; 1/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-2.049, test=-8.866) r2: (train=0.973, test=0.207) total time=   0.3s
# [CV 6/10; 1/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 6/10; 1/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-2.065, test=-7.080) r2: (train=0.972, test=0.517) total time=   0.3s
# [CV 7/10; 1/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 7/10; 1/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.956, test=-6.358) r2: (train=0.976, test=0.515) total time=   0.3s
# [CV 8/10; 1/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 8/10; 1/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.993, test=-11.444) r2: (train=0.971, test=0.347) total time=   0.3s
# [CV 9/10; 1/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 9/10; 1/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.916, test=-7.796) r2: (train=0.972, test=0.487) total time=   0.3s
# [CV 10/10; 1/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 10/10; 1/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.964, test=-5.985) r2: (train=0.975, test=0.671) total time=   0.3s
# [CV 1/10; 2/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 1/10; 2/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.984, test=-8.271) r2: (train=0.975, test=0.058) total time=   0.3s
# [CV 2/10; 2/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 2/10; 2/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.916, test=-6.774) r2: (train=0.976, test=0.565) total time=   0.3s
# [CV 3/10; 2/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 3/10; 2/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-2.024, test=-4.851) r2: (train=0.974, test=0.701) total time=   0.3s
# [CV 4/10; 2/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 4/10; 2/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.866, test=-7.271) r2: (train=0.976, test=0.467) total time=   0.3s
# [CV 5/10; 2/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 5/10; 2/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.988, test=-6.931) r2: (train=0.974, test=0.456) total time=   0.3s
# [CV 6/10; 2/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 6/10; 2/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.912, test=-7.395) r2: (train=0.975, test=0.459) total time=   0.3s
# [CV 7/10; 2/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 7/10; 2/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.888, test=-6.071) r2: (train=0.976, test=0.592) total time=   0.3s
# [CV 8/10; 2/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 8/10; 2/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.946, test=-10.437) r2: (train=0.973, test=0.377) total time=   0.3s
# [CV 9/10; 2/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 9/10; 2/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.888, test=-7.949) r2: (train=0.974, test=0.435) total time=   0.3s
# [CV 10/10; 2/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 10/10; 2/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.989, test=-6.619) r2: (train=0.973, test=0.680) total time=   0.3s
# [CV 1/10; 3/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 1/10; 3/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.935, test=-9.419) r2: (train=0.977, test=-0.129) total time=   0.3s
# [CV 2/10; 3/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 2/10; 3/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.934, test=-7.959) r2: (train=0.975, test=0.407) total time=   0.3s
# [CV 3/10; 3/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 3/10; 3/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-2.008, test=-5.990) r2: (train=0.974, test=0.585) total time=   0.3s
# [CV 4/10; 3/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 4/10; 3/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.894, test=-7.563) r2: (train=0.976, test=0.427) total time=   0.3s
# [CV 5/10; 3/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 5/10; 3/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.968, test=-7.946) r2: (train=0.975, test=0.382) total time=   0.3s
# [CV 6/10; 3/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 6/10; 3/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-2.003, test=-8.372) r2: (train=0.972, test=0.417) total time=   0.3s
# [CV 7/10; 3/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 7/10; 3/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.896, test=-5.657) r2: (train=0.976, test=0.590) total time=   0.3s
# [CV 8/10; 3/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 8/10; 3/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.963, test=-10.753) r2: (train=0.972, test=0.309) total time=   0.3s
# [CV 9/10; 3/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 9/10; 3/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.904, test=-7.597) r2: (train=0.974, test=0.473) total time=   0.3s
# [CV 10/10; 3/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 10/10; 3/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-2.020, test=-6.377) r2: (train=0.974, test=0.692) total time=   0.3s
# [CV 1/10; 4/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 1/10; 4/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-2.004, test=-8.825) r2: (train=0.975, test=0.062) total time=   0.3s
# [CV 2/10; 4/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 2/10; 4/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.961, test=-6.518) r2: (train=0.974, test=0.569) total time=   0.3s
# [CV 3/10; 4/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 3/10; 4/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-2.030, test=-5.885) r2: (train=0.973, test=0.583) total time=   0.3s
# [CV 4/10; 4/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 4/10; 4/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.787, test=-7.759) r2: (train=0.977, test=0.339) total time=   0.3s
# [CV 5/10; 4/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 5/10; 4/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.901, test=-7.144) r2: (train=0.975, test=0.482) total time=   0.3s
# [CV 6/10; 4/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 6/10; 4/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-2.079, test=-7.505) r2: (train=0.972, test=0.464) total time=   0.3s
# [CV 7/10; 4/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 7/10; 4/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.961, test=-6.834) r2: (train=0.975, test=0.552) total time=   0.3s
# [CV 8/10; 4/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 8/10; 4/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-2.012, test=-10.954) r2: (train=0.972, test=0.330) total time=   0.3s
# [CV 9/10; 4/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 9/10; 4/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.993, test=-6.948) r2: (train=0.972, test=0.519) total time=   0.3s
# [CV 10/10; 4/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 10/10; 4/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.965, test=-6.787) r2: (train=0.975, test=0.647) total time=   0.3s
# [CV 1/10; 5/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 1/10; 5/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-2.062, test=-8.988) r2: (train=0.973, test=0.082) total time=   0.3s
# [CV 2/10; 5/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 2/10; 5/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.889, test=-7.134) r2: (train=0.975, test=0.503) total time=   0.3s
# [CV 3/10; 5/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 3/10; 5/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.985, test=-5.537) r2: (train=0.973, test=0.576) total time=   0.3s
# [CV 4/10; 5/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 4/10; 5/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.933, test=-7.531) r2: (train=0.973, test=0.404) total time=   0.3s
# [CV 5/10; 5/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 5/10; 5/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-2.083, test=-7.178) r2: (train=0.971, test=0.509) total time=   0.3s
# [CV 6/10; 5/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 6/10; 5/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-2.146, test=-7.136) r2: (train=0.970, test=0.486) total time=   0.3s
# [CV 7/10; 5/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 7/10; 5/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.986, test=-5.743) r2: (train=0.974, test=0.647) total time=   0.3s
# [CV 8/10; 5/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 8/10; 5/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-2.007, test=-10.360) r2: (train=0.971, test=0.401) total time=   0.3s
# [CV 9/10; 5/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 9/10; 5/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.944, test=-7.120) r2: (train=0.973, test=0.491) total time=   0.3s
# [CV 10/10; 5/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 10/10; 5/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-2.040, test=-6.384) r2: (train=0.972, test=0.674) total time=   0.3s
# [CV 1/10; 6/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 1/10; 6/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.974, test=-9.207) r2: (train=0.975, test=-0.005) total time=   0.3s
# [CV 2/10; 6/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 2/10; 6/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.915, test=-6.981) r2: (train=0.975, test=0.567) total time=   0.3s
# [CV 3/10; 6/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 3/10; 6/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.919, test=-5.884) r2: (train=0.974, test=0.526) total time=   0.3s
# [CV 4/10; 6/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 4/10; 6/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.871, test=-7.160) r2: (train=0.977, test=0.438) total time=   0.3s
# [CV 5/10; 6/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 5/10; 6/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.857, test=-7.589) r2: (train=0.976, test=0.378) total time=   0.3s
# [CV 6/10; 6/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 6/10; 6/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-2.055, test=-7.225) r2: (train=0.970, test=0.476) total time=   0.3s
# [CV 7/10; 6/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 7/10; 6/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.909, test=-5.315) r2: (train=0.977, test=0.661) total time=   0.3s
# [CV 8/10; 6/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 8/10; 6/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.934, test=-10.315) r2: (train=0.972, test=0.340) total time=   0.3s
# [CV 9/10; 6/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 9/10; 6/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.891, test=-7.288) r2: (train=0.973, test=0.418) total time=   0.3s
# [CV 10/10; 6/36] START colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 10/10; 6/36] END colsample_bylevel=0.12, colsample_bytree=0.84, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.988, test=-5.896) r2: (train=0.973, test=0.706) total time=   0.3s
# [CV 1/10; 7/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 1/10; 7/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.991, test=-8.972) r2: (train=0.975, test=-0.042) total time=   0.3s
# [CV 2/10; 7/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 2/10; 7/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.881, test=-7.141) r2: (train=0.975, test=0.521) total time=   0.3s
# [CV 3/10; 7/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 3/10; 7/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-2.033, test=-6.263) r2: (train=0.973, test=0.578) total time=   0.3s
# [CV 4/10; 7/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 4/10; 7/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.870, test=-7.740) r2: (train=0.977, test=0.357) total time=   0.3s
# [CV 5/10; 7/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 5/10; 7/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-2.049, test=-8.866) r2: (train=0.973, test=0.207) total time=   0.3s
# [CV 6/10; 7/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 6/10; 7/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-2.065, test=-7.080) r2: (train=0.972, test=0.517) total time=   0.3s
# [CV 7/10; 7/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 7/10; 7/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.956, test=-6.358) r2: (train=0.976, test=0.515) total time=   0.3s
# [CV 8/10; 7/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 8/10; 7/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.993, test=-11.444) r2: (train=0.971, test=0.347) total time=   0.3s
# [CV 9/10; 7/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 9/10; 7/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.916, test=-7.796) r2: (train=0.972, test=0.487) total time=   0.3s
# [CV 10/10; 7/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 10/10; 7/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.964, test=-5.985) r2: (train=0.975, test=0.671) total time=   0.3s
# [CV 1/10; 8/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 1/10; 8/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.984, test=-8.271) r2: (train=0.975, test=0.058) total time=   0.3s
# [CV 2/10; 8/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 2/10; 8/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.916, test=-6.774) r2: (train=0.976, test=0.565) total time=   0.3s
# [CV 3/10; 8/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 3/10; 8/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-2.024, test=-4.851) r2: (train=0.974, test=0.701) total time=   0.3s
# [CV 4/10; 8/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 4/10; 8/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.866, test=-7.271) r2: (train=0.976, test=0.467) total time=   0.3s
# [CV 5/10; 8/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 5/10; 8/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.988, test=-6.931) r2: (train=0.974, test=0.456) total time=   0.3s
# [CV 6/10; 8/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 6/10; 8/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.912, test=-7.395) r2: (train=0.975, test=0.459) total time=   0.3s
# [CV 7/10; 8/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 7/10; 8/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.888, test=-6.071) r2: (train=0.976, test=0.592) total time=   0.3s
# [CV 8/10; 8/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 8/10; 8/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.946, test=-10.437) r2: (train=0.973, test=0.377) total time=   0.3s
# [CV 9/10; 8/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 9/10; 8/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.888, test=-7.949) r2: (train=0.974, test=0.435) total time=   0.3s
# [CV 10/10; 8/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 10/10; 8/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.989, test=-6.619) r2: (train=0.973, test=0.680) total time=   0.3s
# [CV 1/10; 9/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 1/10; 9/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.935, test=-9.419) r2: (train=0.977, test=-0.129) total time=   0.3s
# [CV 2/10; 9/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 2/10; 9/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.934, test=-7.959) r2: (train=0.975, test=0.407) total time=   0.3s
# [CV 3/10; 9/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 3/10; 9/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-2.008, test=-5.990) r2: (train=0.974, test=0.585) total time=   0.3s
# [CV 4/10; 9/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 4/10; 9/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.894, test=-7.563) r2: (train=0.976, test=0.427) total time=   0.3s
# [CV 5/10; 9/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 5/10; 9/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.968, test=-7.946) r2: (train=0.975, test=0.382) total time=   0.3s
# [CV 6/10; 9/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 6/10; 9/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-2.003, test=-8.372) r2: (train=0.972, test=0.417) total time=   0.3s
# [CV 7/10; 9/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 7/10; 9/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.896, test=-5.657) r2: (train=0.976, test=0.590) total time=   0.3s
# [CV 8/10; 9/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 8/10; 9/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.963, test=-10.753) r2: (train=0.972, test=0.309) total time=   0.3s
# [CV 9/10; 9/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 9/10; 9/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.904, test=-7.597) r2: (train=0.974, test=0.473) total time=   0.3s
# [CV 10/10; 9/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 10/10; 9/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-2.020, test=-6.377) r2: (train=0.974, test=0.692) total time=   0.3s
# [CV 1/10; 10/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 1/10; 10/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-2.004, test=-8.825) r2: (train=0.975, test=0.062) total time=   0.3s
# [CV 2/10; 10/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 2/10; 10/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.961, test=-6.518) r2: (train=0.974, test=0.569) total time=   0.3s
# [CV 3/10; 10/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 3/10; 10/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-2.030, test=-5.885) r2: (train=0.973, test=0.583) total time=   0.3s
# [CV 4/10; 10/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 4/10; 10/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.787, test=-7.759) r2: (train=0.977, test=0.339) total time=   0.3s
# [CV 5/10; 10/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 5/10; 10/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.901, test=-7.144) r2: (train=0.975, test=0.482) total time=   0.3s
# [CV 6/10; 10/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 6/10; 10/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-2.079, test=-7.505) r2: (train=0.972, test=0.464) total time=   0.3s
# [CV 7/10; 10/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 7/10; 10/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.961, test=-6.834) r2: (train=0.975, test=0.552) total time=   0.3s
# [CV 8/10; 10/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 8/10; 10/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-2.012, test=-10.954) r2: (train=0.972, test=0.330) total time=   0.3s
# [CV 9/10; 10/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 9/10; 10/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.993, test=-6.948) r2: (train=0.972, test=0.519) total time=   0.3s
# [CV 10/10; 10/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 10/10; 10/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.965, test=-6.787) r2: (train=0.975, test=0.647) total time=   0.3s
# [CV 1/10; 11/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 1/10; 11/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-2.062, test=-8.988) r2: (train=0.973, test=0.082) total time=   0.3s
# [CV 2/10; 11/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 2/10; 11/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.889, test=-7.134) r2: (train=0.975, test=0.503) total time=   0.3s
# [CV 3/10; 11/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 3/10; 11/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.985, test=-5.537) r2: (train=0.973, test=0.576) total time=   0.3s
# [CV 4/10; 11/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 4/10; 11/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.933, test=-7.531) r2: (train=0.973, test=0.404) total time=   0.3s
# [CV 5/10; 11/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 5/10; 11/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-2.083, test=-7.178) r2: (train=0.971, test=0.509) total time=   0.3s
# [CV 6/10; 11/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 6/10; 11/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-2.146, test=-7.136) r2: (train=0.970, test=0.486) total time=   0.3s
# [CV 7/10; 11/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 7/10; 11/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.986, test=-5.743) r2: (train=0.974, test=0.647) total time=   0.3s
# [CV 8/10; 11/36] START colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 8/10; 11/36] END colsample_bylevel=0.12, colsample_bytree=0.85, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-2.007, test=-10.360) r2: (train=0.971, test=0.401) total time=   0.3s
# ...
# [CV 5/10; 33/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 5/10; 33/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.968, test=-7.946) r2: (train=0.975, test=0.382) total time=   0.3s
# [CV 6/10; 33/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 6/10; 33/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-2.003, test=-8.372) r2: (train=0.972, test=0.417) total time=   0.3s
# [CV 7/10; 33/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 7/10; 33/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.896, test=-5.657) r2: (train=0.976, test=0.590) total time=   0.3s
# [CV 8/10; 33/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 8/10; 33/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.963, test=-10.753) r2: (train=0.972, test=0.309) total time=   0.3s
# [CV 9/10; 33/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 9/10; 33/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.904, test=-7.597) r2: (train=0.974, test=0.473) total time=   0.3s
# [CV 10/10; 33/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 10/10; 33/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.2, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-2.020, test=-6.377) r2: (train=0.974, test=0.692) total time=   0.3s
# [CV 1/10; 34/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 1/10; 34/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-2.004, test=-8.825) r2: (train=0.975, test=0.062) total time=   0.3s
# [CV 2/10; 34/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 2/10; 34/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.961, test=-6.518) r2: (train=0.974, test=0.569) total time=   0.3s
# [CV 3/10; 34/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 3/10; 34/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-2.030, test=-5.885) r2: (train=0.973, test=0.583) total time=   0.3s
# [CV 4/10; 34/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 4/10; 34/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.787, test=-7.759) r2: (train=0.977, test=0.339) total time=   0.3s
# [CV 5/10; 34/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 5/10; 34/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.901, test=-7.144) r2: (train=0.975, test=0.482) total time=   0.3s
# [CV 6/10; 34/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 6/10; 34/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-2.079, test=-7.505) r2: (train=0.972, test=0.464) total time=   0.3s
# [CV 7/10; 34/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 7/10; 34/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.961, test=-6.834) r2: (train=0.975, test=0.552) total time=   0.3s
# [CV 8/10; 34/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 8/10; 34/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-2.012, test=-10.954) r2: (train=0.972, test=0.330) total time=   0.3s
# [CV 9/10; 34/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 9/10; 34/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.993, test=-6.948) r2: (train=0.972, test=0.519) total time=   0.3s
# [CV 10/10; 34/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84
# [CV 10/10; 34/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.84; neg_mean_absolute_error: (train=-1.965, test=-6.787) r2: (train=0.975, test=0.647) total time=   0.3s
# [CV 1/10; 35/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 1/10; 35/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-2.062, test=-8.988) r2: (train=0.973, test=0.082) total time=   0.3s
# [CV 2/10; 35/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 2/10; 35/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.889, test=-7.134) r2: (train=0.975, test=0.503) total time=   0.3s
# [CV 3/10; 35/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 3/10; 35/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.985, test=-5.537) r2: (train=0.973, test=0.576) total time=   0.3s
# [CV 4/10; 35/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 4/10; 35/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.933, test=-7.531) r2: (train=0.973, test=0.404) total time=   0.3s
# [CV 5/10; 35/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 5/10; 35/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-2.083, test=-7.178) r2: (train=0.971, test=0.509) total time=   0.3s
# [CV 6/10; 35/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 6/10; 35/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-2.146, test=-7.136) r2: (train=0.970, test=0.486) total time=   0.3s
# [CV 7/10; 35/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 7/10; 35/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.986, test=-5.743) r2: (train=0.974, test=0.647) total time=   0.3s
# [CV 8/10; 35/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 8/10; 35/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-2.007, test=-10.360) r2: (train=0.971, test=0.401) total time=   0.3s
# [CV 9/10; 35/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 9/10; 35/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-1.944, test=-7.120) r2: (train=0.973, test=0.491) total time=   0.3s
# [CV 10/10; 35/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85
# [CV 10/10; 35/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.85; neg_mean_absolute_error: (train=-2.040, test=-6.384) r2: (train=0.972, test=0.674) total time=   0.3s
# [CV 1/10; 36/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 1/10; 36/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.974, test=-9.207) r2: (train=0.975, test=-0.005) total time=   0.3s
# [CV 2/10; 36/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 2/10; 36/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.915, test=-6.981) r2: (train=0.975, test=0.567) total time=   0.3s
# [CV 3/10; 36/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 3/10; 36/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.919, test=-5.884) r2: (train=0.974, test=0.526) total time=   0.3s
# [CV 4/10; 36/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 4/10; 36/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.871, test=-7.160) r2: (train=0.977, test=0.438) total time=   0.3s
# [CV 5/10; 36/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 5/10; 36/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.857, test=-7.589) r2: (train=0.976, test=0.378) total time=   0.3s
# [CV 6/10; 36/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 6/10; 36/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-2.055, test=-7.225) r2: (train=0.970, test=0.476) total time=   0.3s
# [CV 7/10; 36/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 7/10; 36/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.909, test=-5.315) r2: (train=0.977, test=0.661) total time=   0.3s
# [CV 8/10; 36/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 8/10; 36/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.934, test=-10.315) r2: (train=0.972, test=0.340) total time=   0.3s
# [CV 9/10; 36/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 9/10; 36/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.891, test=-7.288) r2: (train=0.973, test=0.418) total time=   0.3s
# [CV 10/10; 36/36] START colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86
# [CV 10/10; 36/36] END colsample_bylevel=0.13, colsample_bytree=0.86, gamma=100, learning_rate=0.15, max_depth=13, min_child_weight=0.1, n_estimators=1000, subsample=0.86; neg_mean_absolute_error: (train=-1.988, test=-5.896) r2: (train=0.973, test=0.706) total time=   0.3s

# %% [markdown]
# Apply chosen hyperparams

# %%
cv_results_ = pd.read_csv('/content/grid_search_w_xgb_f.csv')

# %% [markdown]
# Test on a Validation set

# %%
### THIS IS NOT NECESSARY, JUST A SANITY CHECK WHICH CONFIRMS THE NUMBERS FROM THE .csv ############

from sklearn import model_selection
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold
from statistics import mean

# Create the parameter grid based on the results of random search

chosen_index = 550 #grid_search_w_xgb_f.csv

print(cv_results_['params'][chosen_index])
tv_rf = xgb.XGBRegressor(
    objective='reg:squarederror',
    max_depth = cv_results_['param_max_depth'][chosen_index],
    min_child_weight = cv_results_['param_min_child_weight'][chosen_index],
    gamma = cv_results_['param_gamma'][chosen_index],
    learning_rate = cv_results_['param_learning_rate'][chosen_index],
    subsample = cv_results_['param_subsample'][chosen_index],
    colsample_bylevel = cv_results_['param_colsample_bylevel'][chosen_index],
    colsample_bytree = cv_results_['param_colsample_bytree'][chosen_index]
)

# evaluate the model
cv = StratifiedKFold(n_splits=10, shuffle = True, random_state=42)
mae_v = cross_val_score(tv_rf, X_TV, Y_TV, scoring='neg_mean_absolute_error', cv=10, n_jobs=1)

# report performance
print('MAE:', (mean(mae_v)*(-1), "Standard deviation: ", np.std(mae_v)))

r2_v = cross_val_score(tv_rf, X_TV, Y_TV, scoring='r2', cv=10, n_jobs=1)
print('R2', (mean(r2_v), "Standard deviation: ", np.std(r2_v)))
# Out:
# {'subsample': 0.85, 'min_child_weight': 0.1, 'max_depth': 13, 'learning_rate': 0.2, 'gamma': 100, 'colsample_bytree': 0.84, 'colsample_bylevel': 0.13}
# MAE: (7.25952990046819, 'Standard deviation: ', 1.4473279360492428)
# R2 (0.49378936154424286, 'Standard deviation: ', 0.16551793619682434)

# %% [markdown]
# Read Train + Validation results

# %%
chosen_index = 550 #grid_search_w_xgb_f.csv

r2_v = []
mae_v = []
r2_tr = []
mae_tr = []

for i in range (10):
  v_r2 = "split"+str(i)+"_test_r2"  
  v_mae = "split"+str(i)+"_test_neg_mean_absolute_error"
  r2_v.append(cv_results_[v_r2][chosen_index])
  mae_v.append(cv_results_[v_mae][chosen_index]*(-1))

  tr_r2 = "split"+str(i)+"_train_r2"  
  tr_mae = "split"+str(i)+"_train_neg_mean_absolute_error"
  r2_tr.append(cv_results_[tr_r2][chosen_index])
  mae_tr.append(cv_results_[tr_mae][chosen_index]*(-1))

print("Validation r2 score: ", round(cv_results_['mean_test_r2'][chosen_index],2), "\n Standard deviation: ", round(cv_results_['std_test_r2'][chosen_index],2) )
print("Train r2 score: ", round(cv_results_['mean_train_r2'][chosen_index],2),"\n Standard deviation: ", round(cv_results_['std_train_r2'][chosen_index],2))
print("Validation MAE score: ", round(cv_results_['mean_test_neg_mean_absolute_error'][chosen_index],2), "\n Standard deviation: ", round(cv_results_['std_test_neg_mean_absolute_error'][chosen_index],2) )
print("Train MAE score: ", round(cv_results_['mean_train_neg_mean_absolute_error'][chosen_index],2),"\n Standard deviation: ", round(cv_results_['std_train_neg_mean_absolute_error'][chosen_index],2))
metrics_TV = pd.DataFrame(list(zip(r2_v,mae_v,r2_tr,mae_tr)), columns =['r2_validation', 'MAE_validation', 'r2_train', 'MAE_train',])

sns.set(font_scale=2)
f = plt.figure(figsize=(25,16))
gs = f.add_gridspec(2, 2)
gs.update(wspace = 0.1, hspace = 0.3)


with sns.axes_style("ticks"):
    ax = f.add_subplot(gs[0, 0])
    sns.boxplot(data=metrics_TV, x="r2_validation", color = "forestgreen", boxprops=dict(alpha=.5)).set(
    xlabel='R2 score results on validation set')
    plt.xlim(0.1,0.9)
    ax.xaxis.labelpad = 20

with sns.axes_style("ticks"):
    ax = f.add_subplot(gs[0, 1])
    sns.boxplot(data=metrics_TV, x="r2_train", color = "forestgreen", boxprops=dict(alpha=.5)).set(
    xlabel='R2 score results on train set')
    plt.xlim(0.95,1)
    ax.xaxis.labelpad = 20


with sns.axes_style("ticks"):
    ax = f.add_subplot(gs[1, 0])
    sns.boxplot(data=metrics_TV, x="MAE_validation", color = "forestgreen", boxprops=dict(alpha=.5)).set(
    xlabel='MAE score results on validation set')
    ax.xaxis.labelpad = 20
    plt.xlim(4,10)
    
with sns.axes_style("ticks"):
    ax = f.add_subplot(gs[1, 1])
    sns.boxplot(data=metrics_TV, x="MAE_train", color = "forestgreen", boxprops=dict(alpha=.5)).set(
    xlabel='MAE score results on train set')
    plt.xlim(2,2.5)
    ax.xaxis.labelpad = 20

f.savefig('wood_xb.png')
# Out:
# Validation r2 score:  0.49
#  Standard deviation:  0.17
# Train r2 score:  0.96
#  Standard deviation:  0.0
# Validation MAE score:  -7.26
#  Standard deviation:  1.45
# Train MAE score:  -2.35
#  Standard deviation:  0.08

# %% [markdown]
# Hyperparameters applied to (T) set

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor

r2=[]
MAE=[]

t_rf = xgb.XGBRegressor(
    objective='reg:squarederror',
    max_depth = cv_results_['param_max_depth'][chosen_index],
    min_child_weight = cv_results_['param_min_child_weight'][chosen_index],
    gamma = cv_results_['param_gamma'][chosen_index],
    learning_rate = cv_results_['param_learning_rate'][chosen_index],
    subsample = cv_results_['param_subsample'][chosen_index],
    colsample_bylevel = cv_results_['param_colsample_bylevel'][chosen_index],
    colsample_bytree = cv_results_['param_colsample_bytree'][chosen_index]
)


t_rf.fit(X_TV, Y_TV)

# Get Y predicted
predictions=t_rf.predict(X_T)

# Print out the mean absolute error (mae)
MAE = round(mean_absolute_error(Y_T, predictions),2)
print('Mean Absolute Error:', MAE)

# Print out R2
print('R2:', round(r2_score(Y_T, predictions),2))
# Out:
# Mean Absolute Error: 6.53
# R2: 0.59

# %% [markdown]
# Fitted vs Actual plot (Test set)

# %%
# Visualising  results
predictions = t_rf.predict(X_T)
mae = np.round(abs(Y_T - predictions))
d = {'label': Y_T, 'prediction': predictions, 'mae': mae}
plot = pd.DataFrame(data = d)
# plot absolute settings
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_style("whitegrid", {"grid.color": ".9"})

points = plt.scatter(d["label"], d["prediction"], s=50, c=d["mae"], cmap="crest")
plt.colorbar(points)
plt.xlim(0, 67)
plt.ylim(0, 67)

sns.regplot(
    x="label", y="prediction", data=plot, scatter = False, color='g')

# %% [markdown]
# Absolute error in the test set plot

# %%
# Visualising the Random Forest Regression results
n = 69 #number of data points


sns.set_style("whitegrid", {"grid.color": ".9"})
numbers = np.array(list(range(0,int(n),+1)))

value = np.round(abs(Y_test - predictions))
d = {'Absolute error': value, 'dataset': numbers}
plot = pd.DataFrame(data = d)

sns.displot(data = plot, x="dataset", y="Absolute error", height=7,
    aspect=1, binwidth=(4, 4), cmap="YlOrBr")

sns.lineplot(data = plot, x="dataset", y=MAE, color = 'chocolate')
# Out:
# <AxesSubplot:xlabel='dataset', ylabel='Absolute error'>

# %%
pip install shap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: shap in /usr/local/lib/python3.7/dist-packages (0.41.0)
# Requirement already satisfied: slicer==0.0.7 in /usr/local/lib/python3.7/dist-packages (from shap) (0.0.7)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from shap) (1.7.3)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.7/dist-packages (from shap) (21.3)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from shap) (0.56.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from shap) (1.3.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from shap) (1.0.2)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from shap) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from shap) (1.21.6)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.7/dist-packages (from shap) (4.64.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>20.9->shap) (3.0.9)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->shap) (4.12.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->shap) (0.39.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->shap) (57.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->shap) (3.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->shap) (4.1.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (1.1.0)

# %% [markdown]
# Feature importance

# %%
import shap
from scipy.special import softmax
from sklearn.feature_selection import SelectFwe, chi2

def print_feature_importances_random_forest(random_forest_model):
    
    '''
    Prints the feature importances of a Random Forest model in an ordered way.
    random_forest_model -> The sklearn.ensemble.RandomForestRegressor or RandomForestClassifier trained model
    '''
    
    # Fetch the feature importances and feature names
    importances = t_rf.feature_importances_
    features = headers
    
    # Organize them in a dictionary
    feature_importances = {fea: imp for imp, fea in zip(importances, features)}
    
    # Sorts the dictionary
    feature_importances = {k: v for k, v in sorted(feature_importances.items(), key=lambda item: item[1], reverse = True)}
    
    # Prints the feature importances
    for k, v in feature_importances.items():
        print(f"{k} -> {v:.4f}")

def print_feature_importances_shap_values(shap_values, features):
    
    '''
    Prints the feature importances based on SHAP values in an ordered way
    shap_values -> The SHAP values calculated from a shap.Explainer object
    features -> The name of the features, on the order presented to the explainer
    '''

    # Calculates the feature importance (mean absolute shap value) for each feature
    importances = []
    for i in range(shap_values.values.shape[1]):
        importances.append(np.mean(np.abs(shap_values.values[:, i])))
        
    # Calculates the normalized version
    importances_norm = softmax(importances)

    # Organize the importances and columns in a dictionary
    feature_importances = {fea: imp for imp, fea in zip(importances, features)}
    feature_importances_norm = {fea: imp for imp, fea in zip(importances_norm, features)}

    # Sorts the dictionary
    feature_importances = {k: v for k, v in sorted(feature_importances.items(), key=lambda item: item[1], reverse = True)}
    feature_importances_norm= {k: v for k, v in sorted(feature_importances_norm.items(), key=lambda item: item[1], reverse = True)}

    # Prints the feature importances
    for k, v in feature_importances.items():
        print(f"{k} -> {v:.4f} (softmax = {feature_importances_norm[k]:.4f})")

# %%
# Prints the feature importances
print_feature_importances_random_forest(t_rf)
# Out:
# KREIS_6 -> 0.0986
# ZIPCODE_8002 -> 0.0740
# AREA_F -> 0.0506
# ZIPCODE_8057 -> 0.0462
# ZIPCODE_8052 -> 0.0460
# KREIS_11 -> 0.0419
# VOL -> 0.0379
# ST_NUM -> 0.0371
# POC_1946 - 1960 -> 0.0357
# YOC -> 0.0352
# ZIPCODE_8051 -> 0.0338
# KREIS_9 -> 0.0333
# KREIS_7 -> 0.0328
# POC_1919 - 1945 -> 0.0309
# ZIPCODE_8004 -> 0.0292
# APT_NUM -> 0.0257
# ZIPCODE_8048 -> 0.0225
# ZIPCODE_8055 -> 0.0223
# ZIPCODE_8044 -> 0.0216
# ZIPCODE_8038 -> 0.0184
# KREIS_10 -> 0.0176
# ZIPCODE_8032 -> 0.0174
# KREIS_4 -> 0.0143
# KREIS_12 -> 0.0141
# ZIPCODE_8053 -> 0.0136
# ROOF_F -> 0.0132
# ZIPCODE_8008 -> 0.0131
# ROOF_P -> 0.0122
# POC_1961 - 1970 -> 0.0120
# ZIPCODE_8046 -> 0.0119
# KREIS_2 -> 0.0112
# ZIPCODE_8047 -> 0.0111
# KREIS_3 -> 0.0102
# ZIPCODE_8049 -> 0.0097
# ROOF_M -> 0.0097
# KREIS_8 -> 0.0089
# POC_1900 - 1919 -> 0.0084
# ZIPCODE_8050 -> 0.0084
# ROOF_O -> 0.0074
# ZIPCODE_8006 -> 0.0015
# ZIPCODE_8045 -> 0.0004
# POC_1971 - 1980 -> 0.0002
# ZIPCODE_8003 -> 0.0000

# %%
import shap
# Fits the explainer
explainer = shap.Explainer(t_rf, feature_names= headers)
# Calculates the SHAP values - It takes some time
shap_values = explainer(X)

# %%
shap.summary_plot(shap_values)

import matplotlib.pyplot as pl
fig = pl.gcf()
fig.savefig('wood_xb_imp.png')
