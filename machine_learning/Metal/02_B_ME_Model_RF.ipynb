# %% [markdown]
# Import libraries, check your DataFrame

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
import sklearn

# %%
new_data = pd.read_csv('/content/metal.csv')
new_data = new_data.drop(columns=new_data.columns[0])

# %%
new_data.describe()
# Out:
#                VOL      AREA_F     APT_NUM      ST_NUM      KREIS  \
# count   277.000000  277.000000  277.000000  277.000000  277.00000
# mean   1502.382671  147.148014    4.740072    4.577617    7.65704
# std     722.392501   47.132904    2.822840    0.973529    3.14874
# min     226.000000   52.000000    1.000000    1.000000    2.00000
# 25%     915.000000  115.000000    2.000000    4.000000    6.00000
# 50%    1529.000000  161.000000    6.000000    5.000000    9.00000
# 75%    1873.000000  175.000000    6.000000    5.000000   11.00000
# max    3445.000000  258.000000   13.000000    7.000000   12.00000
#
#            ZIPCODE          YOC       METAL
# count   277.000000   277.000000  277.000000
# mean   8044.108303  1942.187726   33.594874
# std      15.230446    12.181038   41.572061
# min    8002.000000  1904.000000    0.050000
# 25%    8045.000000  1933.000000    5.050000
# 50%    8048.000000  1948.000000   14.310000
# 75%    8052.000000  1950.000000   45.000000
# max    8057.000000  1972.000000  157.340000

# %% [markdown]
# One-hot encode of categorical data

# %%
new_data['KREIS'] = new_data['KREIS'].astype('category')
new_data['ZIPCODE'] = new_data['ZIPCODE'].astype('category')
# One-hot encode the data using pandas get_dummies
new_data = pd.get_dummies(new_data)
print
print(new_data.columns)
print(new_data.shape)
# Out:
# Index(['VOL', 'AREA_F', 'APT_NUM', 'ST_NUM', 'YOC', 'METAL', 'KREIS_2',
#        'KREIS_3', 'KREIS_4', 'KREIS_6', 'KREIS_7', 'KREIS_8', 'KREIS_9',
#        'KREIS_10', 'KREIS_11', 'KREIS_12', 'ZIPCODE_8002', 'ZIPCODE_8004',
#        'ZIPCODE_8006', 'ZIPCODE_8008', 'ZIPCODE_8032', 'ZIPCODE_8038',
#        'ZIPCODE_8044', 'ZIPCODE_8045', 'ZIPCODE_8046', 'ZIPCODE_8047',
#        'ZIPCODE_8048', 'ZIPCODE_8049', 'ZIPCODE_8050', 'ZIPCODE_8051',
#        'ZIPCODE_8052', 'ZIPCODE_8053', 'ZIPCODE_8055', 'ZIPCODE_8057',
#        'ROOF_F', 'ROOF_M', 'ROOF_O', 'ROOF_P', 'POC_1900 - 1919',
#        'POC_1919 - 1945', 'POC_1946 - 1960', 'POC_1961 - 1970',
#        'POC_1971 - 1980'],
#       dtype='object')
# (277, 43)

# %% [markdown]
# Split data into an hold-out TEST set (T) and train + validation set (TV)

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

material = 'METAL'

# labels as numpy array
Y=np.array(new_data[material])

#features as numpy array
X_list= new_data.drop(columns=material)
X = np.array(X_list)

#save headers for later
headers = list(X_list.columns)

X_TV, X_T, Y_TV, Y_T = train_test_split(X,Y,test_size = 0.15, random_state = 296) #this split, meaning, this random seed, has to be the same for all the models!

print(X_T, Y_T)
# Out:
# [[1656  152    6 ...    0    0    0]
#  [1172  176    5 ...    1    0    0]
#  [1306  187    4 ...    1    0    0]
#  ...
#  [1028   95    6 ...    1    0    0]
#  [ 802  115    2 ...    1    0    0]
#  [ 703  113    1 ...    1    0    0]] [ 43.11   4.19  87.84   6.51   9.2    4.69 105.99   3.89  30.    16.88
#   75.     3.63  56.54  20.    14.59  28.5   16.88  28.85  68.18  69.2
#   45.     0.84   4.85   7.62  37.5   84.68   2.52  90.8   91.27   9.62
#  135.33  17.41  12.5    6.   110.15  17.62  17.09  67.79   7.5    9.49
#   53.94   1.  ]

# %% [markdown]
# Different methods of parameters tuning

# %% [markdown]
# RandomizedSearchCV on non-log-transformed label

# %%
model_pipe =RandomForestRegressor()

#Metrics for Evualation:
met_grid= ['r2', 'neg_mean_absolute_error'] #The metric codes from sklearn

# Create the parameter grid based on the results of random search 
params = {
          'max_depth': [3,4,5,7,10,11,12,13,None],
          'max_features': ['sqrt',0.3, 0.4, 0.5, 0.6, None, 'log2'],
          'n_estimators': [800, 1000],
          'min_samples_leaf' : [1,2,3,4],
          'bootstrap' : [True, False],
          'min_impurity_decrease' : [0, 0.01, 0.05, 0.1],
          'ccp_alpha' : [0, 0.01, 0.05, 0.1]
      }

# Instantiate the grid search model
grid_search = RandomizedSearchCV(model_pipe, param_distributions = params, scoring = met_grid, refit = 'r2', n_iter = 500,
                                cv = 10, n_jobs = 1, verbose = 10, return_train_score = True)
# Fit the grid search to the data
grid_search.fit(X_TV, Y_TV)

print(pd.DataFrame(grid_search.cv_results_))
print(grid_search.best_params_)

from google.colab import files

gd_mi = pd.DataFrame(grid_search.cv_results_)
gd_mi.to_csv('grid_search_me.csv', encoding = 'utf-8-sig') 
files.download('grid_search_me.csv')
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# [CV 3/10; 258/500] END bootstrap=True, ccp_alpha=0, max_depth=None, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-4.980, test=-19.299) r2: (train=0.950, test=0.510) total time=   1.3s
# [CV 4/10; 258/500] START bootstrap=True, ccp_alpha=0, max_depth=None, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 4/10; 258/500] END bootstrap=True, ccp_alpha=0, max_depth=None, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.402, test=-14.929) r2: (train=0.947, test=0.558) total time=   1.2s
# [CV 5/10; 258/500] START bootstrap=True, ccp_alpha=0, max_depth=None, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 5/10; 258/500] END bootstrap=True, ccp_alpha=0, max_depth=None, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.374, test=-11.753) r2: (train=0.949, test=0.630) total time=   1.2s
# [CV 6/10; 258/500] START bootstrap=True, ccp_alpha=0, max_depth=None, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 6/10; 258/500] END bootstrap=True, ccp_alpha=0, max_depth=None, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.519, test=-13.358) r2: (train=0.947, test=0.604) total time=   1.2s
# [CV 7/10; 258/500] START bootstrap=True, ccp_alpha=0, max_depth=None, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 7/10; 258/500] END bootstrap=True, ccp_alpha=0, max_depth=None, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.018, test=-17.758) r2: (train=0.951, test=0.275) total time=   1.2s
# [CV 8/10; 258/500] START bootstrap=True, ccp_alpha=0, max_depth=None, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 8/10; 258/500] END bootstrap=True, ccp_alpha=0, max_depth=None, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.483, test=-10.173) r2: (train=0.948, test=0.572) total time=   1.2s
# [CV 9/10; 258/500] START bootstrap=True, ccp_alpha=0, max_depth=None, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 9/10; 258/500] END bootstrap=True, ccp_alpha=0, max_depth=None, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.180, test=-15.264) r2: (train=0.949, test=0.602) total time=   1.3s
# [CV 10/10; 258/500] START bootstrap=True, ccp_alpha=0, max_depth=None, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 10/10; 258/500] END bootstrap=True, ccp_alpha=0, max_depth=None, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.298, test=-16.535) r2: (train=0.948, test=0.604) total time=   1.2s
# [CV 1/10; 259/500] START bootstrap=True, ccp_alpha=0.05, max_depth=13, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=3, n_estimators=1000
# [CV 1/10; 259/500] END bootstrap=True, ccp_alpha=0.05, max_depth=13, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-13.553, test=-9.532) r2: (train=0.744, test=0.863) total time=   1.6s
# [CV 2/10; 259/500] START bootstrap=True, ccp_alpha=0.05, max_depth=13, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=3, n_estimators=1000
# [CV 2/10; 259/500] END bootstrap=True, ccp_alpha=0.05, max_depth=13, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-13.384, test=-17.280) r2: (train=0.737, test=0.736) total time=   1.8s
# [CV 3/10; 259/500] START bootstrap=True, ccp_alpha=0.05, max_depth=13, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=3, n_estimators=1000
# [CV 3/10; 259/500] END bootstrap=True, ccp_alpha=0.05, max_depth=13, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-12.363, test=-22.282) r2: (train=0.767, test=0.518) total time=   2.3s
# [CV 4/10; 259/500] START bootstrap=True, ccp_alpha=0.05, max_depth=13, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=3, n_estimators=1000
# [CV 4/10; 259/500] END bootstrap=True, ccp_alpha=0.05, max_depth=13, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-12.925, test=-17.707) r2: (train=0.763, test=0.556) total time=   1.6s
# [CV 5/10; 259/500] START bootstrap=True, ccp_alpha=0.05, max_depth=13, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=3, n_estimators=1000
# [CV 5/10; 259/500] END bootstrap=True, ccp_alpha=0.05, max_depth=13, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-13.300, test=-13.478) r2: (train=0.755, test=0.650) total time=   1.5s
# [CV 6/10; 259/500] START bootstrap=True, ccp_alpha=0.05, max_depth=13, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=3, n_estimators=1000
# [CV 6/10; 259/500] END bootstrap=True, ccp_alpha=0.05, max_depth=13, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-13.324, test=-13.201) r2: (train=0.754, test=0.701) total time=   1.5s
# [CV 7/10; 259/500] START bootstrap=True, ccp_alpha=0.05, max_depth=13, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=3, n_estimators=1000
# [CV 7/10; 259/500] END bootstrap=True, ccp_alpha=0.05, max_depth=13, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-12.407, test=-18.528) r2: (train=0.769, test=0.354) total time=   1.5s
# [CV 8/10; 259/500] START bootstrap=True, ccp_alpha=0.05, max_depth=13, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=3, n_estimators=1000
# [CV 8/10; 259/500] END bootstrap=True, ccp_alpha=0.05, max_depth=13, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-13.009, test=-13.679) r2: (train=0.768, test=0.544) total time=   1.5s
# [CV 9/10; 259/500] START bootstrap=True, ccp_alpha=0.05, max_depth=13, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=3, n_estimators=1000
# [CV 9/10; 259/500] END bootstrap=True, ccp_alpha=0.05, max_depth=13, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-12.430, test=-19.217) r2: (train=0.766, test=0.534) total time=   1.5s
# [CV 10/10; 259/500] START bootstrap=True, ccp_alpha=0.05, max_depth=13, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=3, n_estimators=1000
# [CV 10/10; 259/500] END bootstrap=True, ccp_alpha=0.05, max_depth=13, max_features=sqrt, min_impurity_decrease=0.05, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-13.026, test=-17.423) r2: (train=0.757, test=0.662) total time=   1.5s
# [CV 1/10; 260/500] START bootstrap=True, ccp_alpha=0.1, max_depth=3, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=2, n_estimators=1000
# [CV 1/10; 260/500] END bootstrap=True, ccp_alpha=0.1, max_depth=3, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=2, n_estimators=1000; neg_mean_absolute_error: (train=-17.182, test=-13.540) r2: (train=0.638, test=0.796) total time=   1.5s
# [CV 2/10; 260/500] START bootstrap=True, ccp_alpha=0.1, max_depth=3, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=2, n_estimators=1000
# [CV 2/10; 260/500] END bootstrap=True, ccp_alpha=0.1, max_depth=3, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=2, n_estimators=1000; neg_mean_absolute_error: (train=-16.575, test=-17.218) r2: (train=0.644, test=0.709) total time=   1.5s
# [CV 3/10; 260/500] START bootstrap=True, ccp_alpha=0.1, max_depth=3, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=2, n_estimators=1000
# [CV 3/10; 260/500] END bootstrap=True, ccp_alpha=0.1, max_depth=3, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=2, n_estimators=1000; neg_mean_absolute_error: (train=-15.810, test=-22.970) r2: (train=0.675, test=0.476) total time=   1.5s
# [CV 4/10; 260/500] START bootstrap=True, ccp_alpha=0.1, max_depth=3, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=2, n_estimators=1000
# [CV 4/10; 260/500] END bootstrap=True, ccp_alpha=0.1, max_depth=3, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=2, n_estimators=1000; neg_mean_absolute_error: (train=-16.208, test=-20.470) r2: (train=0.656, test=0.510) total time=   1.5s
# [CV 5/10; 260/500] START bootstrap=True, ccp_alpha=0.1, max_depth=3, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=2, n_estimators=1000
# [CV 5/10; 260/500] END bootstrap=True, ccp_alpha=0.1, max_depth=3, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=2, n_estimators=1000; neg_mean_absolute_error: (train=-16.657, test=-15.594) r2: (train=0.659, test=0.626) total time=   1.5s
# [CV 6/10; 260/500] START bootstrap=True, ccp_alpha=0.1, max_depth=3, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=2, n_estimators=1000
# [CV 6/10; 260/500] END bootstrap=True, ccp_alpha=0.1, max_depth=3, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=2, n_estimators=1000; neg_mean_absolute_error: (train=-17.070, test=-16.906) r2: (train=0.652, test=0.627) total time=   1.5s
# [CV 7/10; 260/500] START bootstrap=True, ccp_alpha=0.1, max_depth=3, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=2, n_estimators=1000
# [CV 7/10; 260/500] END bootstrap=True, ccp_alpha=0.1, max_depth=3, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=2, n_estimators=1000; neg_mean_absolute_error: (train=-15.489, test=-22.078) r2: (train=0.679, test=0.217) total time=   1.5s
# [CV 8/10; 260/500] START bootstrap=True, ccp_alpha=0.1, max_depth=3, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=2, n_estimators=1000
# [CV 8/10; 260/500] END bootstrap=True, ccp_alpha=0.1, max_depth=3, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=2, n_estimators=1000; neg_mean_absolute_error: (train=-16.549, test=-16.575) r2: (train=0.669, test=0.527) total time=   1.5s
# [CV 9/10; 260/500] START bootstrap=True, ccp_alpha=0.1, max_depth=3, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=2, n_estimators=1000
# [CV 9/10; 260/500] END bootstrap=True, ccp_alpha=0.1, max_depth=3, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=2, n_estimators=1000; neg_mean_absolute_error: (train=-15.753, test=-22.130) r2: (train=0.674, test=0.446) total time=   1.5s
# [CV 10/10; 260/500] START bootstrap=True, ccp_alpha=0.1, max_depth=3, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=2, n_estimators=1000
# [CV 10/10; 260/500] END bootstrap=True, ccp_alpha=0.1, max_depth=3, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=2, n_estimators=1000; neg_mean_absolute_error: (train=-16.542, test=-16.401) r2: (train=0.659, test=0.672) total time=   1.5s
# [CV 1/10; 261/500] START bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=log2, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 1/10; 261/500] END bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=log2, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-14.216, test=-11.420) r2: (train=0.747, test=0.846) total time=   0.9s
# [CV 2/10; 261/500] START bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=log2, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 2/10; 261/500] END bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=log2, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-13.535, test=-15.446) r2: (train=0.757, test=0.761) total time=   0.9s
# [CV 3/10; 261/500] START bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=log2, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 3/10; 261/500] END bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=log2, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-12.734, test=-21.477) r2: (train=0.788, test=0.525) total time=   0.9s
# [CV 4/10; 261/500] START bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=log2, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 4/10; 261/500] END bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=log2, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-13.550, test=-18.799) r2: (train=0.750, test=0.509) total time=   0.9s
# [CV 5/10; 261/500] START bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=log2, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 5/10; 261/500] END bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=log2, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-13.620, test=-15.714) r2: (train=0.766, test=0.601) total time=   0.9s
# [CV 6/10; 261/500] START bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=log2, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 6/10; 261/500] END bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=log2, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-14.027, test=-15.441) r2: (train=0.756, test=0.628) total time=   0.9s
# [CV 7/10; 261/500] START bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=log2, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 7/10; 261/500] END bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=log2, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-12.710, test=-20.127) r2: (train=0.780, test=0.308) total time=   0.9s
# [CV 8/10; 261/500] START bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=log2, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 8/10; 261/500] END bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=log2, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-13.521, test=-14.171) r2: (train=0.777, test=0.572) total time=   0.9s
# [CV 9/10; 261/500] START bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=log2, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 9/10; 261/500] END bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=log2, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-13.077, test=-20.345) r2: (train=0.771, test=0.515) total time=   0.9s
# [CV 10/10; 261/500] START bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=log2, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 10/10; 261/500] END bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=log2, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-13.336, test=-17.971) r2: (train=0.772, test=0.646) total time=   0.9s
# [CV 1/10; 262/500] START bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 1/10; 262/500] END bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-11.588, test=-9.002) r2: (train=0.781, test=0.831) total time=   1.0s
# [CV 2/10; 262/500] START bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 2/10; 262/500] END bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-10.897, test=-13.769) r2: (train=0.792, test=0.776) total time=   1.0s
# [CV 3/10; 262/500] START bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 3/10; 262/500] END bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-10.733, test=-20.054) r2: (train=0.819, test=0.516) total time=   1.0s
# [CV 4/10; 262/500] START bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 4/10; 262/500] END bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-11.186, test=-17.146) r2: (train=0.788, test=0.538) total time=   0.9s
# [CV 5/10; 262/500] START bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 5/10; 262/500] END bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-11.510, test=-13.721) r2: (train=0.786, test=0.617) total time=   1.0s
# [CV 6/10; 262/500] START bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 6/10; 262/500] END bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-11.907, test=-15.912) r2: (train=0.788, test=0.581) total time=   1.0s
# [CV 7/10; 262/500] START bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 7/10; 262/500] END bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-10.820, test=-20.586) r2: (train=0.811, test=0.292) total time=   0.9s
# [CV 8/10; 262/500] START bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 8/10; 262/500] END bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-11.263, test=-12.234) r2: (train=0.813, test=0.574) total time=   1.0s
# [CV 9/10; 262/500] START bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 9/10; 262/500] END bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-10.969, test=-18.346) r2: (train=0.799, test=0.532) total time=   1.0s
# [CV 10/10; 262/500] START bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 10/10; 262/500] END bootstrap=False, ccp_alpha=0.05, max_depth=5, max_features=0.4, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-11.361, test=-17.079) r2: (train=0.804, test=0.631) total time=   1.0s
# [CV 1/10; 263/500] START bootstrap=True, ccp_alpha=0.05, max_depth=7, max_features=0.3, min_impurity_decrease=0.1, min_samples_leaf=1, n_estimators=800
# [CV 1/10; 263/500] END bootstrap=True, ccp_alpha=0.05, max_depth=7, max_features=0.3, min_impurity_decrease=0.1, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-9.822, test=-7.376) r2: (train=0.852, test=0.874) total time=   1.3s
# [CV 2/10; 263/500] START bootstrap=True, ccp_alpha=0.05, max_depth=7, max_features=0.3, min_impurity_decrease=0.1, min_samples_leaf=1, n_estimators=800
# [CV 2/10; 263/500] END bootstrap=True, ccp_alpha=0.05, max_depth=7, max_features=0.3, min_impurity_decrease=0.1, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-9.196, test=-12.662) r2: (train=0.861, test=0.800) total time=   1.3s
# [CV 3/10; 263/500] START bootstrap=True, ccp_alpha=0.05, max_depth=7, max_features=0.3, min_impurity_decrease=0.1, min_samples_leaf=1, n_estimators=800
# [CV 3/10; 263/500] END bootstrap=True, ccp_alpha=0.05, max_depth=7, max_features=0.3, min_impurity_decrease=0.1, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-8.644, test=-19.676) r2: (train=0.879, test=0.515) total time=   1.3s
# [CV 4/10; 263/500] START bootstrap=True, ccp_alpha=0.05, max_depth=7, max_features=0.3, min_impurity_decrease=0.1, min_samples_leaf=1, n_estimators=800
# [CV 4/10; 263/500] END bootstrap=True, ccp_alpha=0.05, max_depth=7, max_features=0.3, min_impurity_decrease=0.1, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-9.341, test=-16.501) r2: (train=0.859, test=0.569) total time=   1.3s
# [CV 5/10; 263/500] START bootstrap=True, ccp_alpha=0.05, max_depth=7, max_features=0.3, min_impurity_decrease=0.1, min_samples_leaf=1, n_estimators=800
# [CV 5/10; 263/500] END bootstrap=True, ccp_alpha=0.05, max_depth=7, max_features=0.3, min_impurity_decrease=0.1, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-9.491, test=-12.539) r2: (train=0.863, test=0.670) total time=   1.3s
# [CV 6/10; 263/500] START bootstrap=True, ccp_alpha=0.05, max_depth=7, max_features=0.3, min_impurity_decrease=0.1, min_samples_leaf=1, n_estimators=800
# [CV 6/10; 263/500] END bootstrap=True, ccp_alpha=0.05, max_depth=7, max_features=0.3, min_impurity_decrease=0.1, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-9.646, test=-14.696) r2: (train=0.858, test=0.597) total time=   1.3s
# [CV 7/10; 263/500] START bootstrap=True, ccp_alpha=0.05, max_depth=7, max_features=0.3, min_impurity_decrease=0.1, min_samples_leaf=1, n_estimators=800
# [CV 7/10; 263/500] END bootstrap=True, ccp_alpha=0.05, max_depth=7, max_features=0.3, min_impurity_decrease=0.1, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-8.538, test=-19.847) r2: (train=0.878, test=0.263) total time=   1.3s
# [CV 8/10; 263/500] START bootstrap=True, ccp_alpha=0.05, max_depth=7, max_features=0.3, min_impurity_decrease=0.1, min_samples_leaf=1, n_estimators=800
# [CV 8/10; 263/500] END bootstrap=True, ccp_alpha=0.05, max_depth=7, max_features=0.3, min_impurity_decrease=0.1, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-9.153, test=-11.255) r2: (train=0.876, test=0.564) total time=   1.3s
# [CV 9/10; 263/500] START bootstrap=True, ccp_alpha=0.05, max_depth=7, max_features=0.3, min_impurity_decrease=0.1, min_samples_leaf=1, n_estimators=800
# [CV 9/10; 263/500] END bootstrap=True, ccp_alpha=0.05, max_depth=7, max_features=0.3, min_impurity_decrease=0.1, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-8.894, test=-17.111) r2: (train=0.869, test=0.560) total time=   1.3s
# [CV 10/10; 263/500] START bootstrap=True, ccp_alpha=0.05, max_depth=7, max_features=0.3, min_impurity_decrease=0.1, min_samples_leaf=1, n_estimators=800
# [CV 10/10; 263/500] END bootstrap=True, ccp_alpha=0.05, max_depth=7, max_features=0.3, min_impurity_decrease=0.1, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-9.155, test=-16.340) r2: (train=0.870, test=0.627) total time=   1.3s
# [CV 1/10; 264/500] START bootstrap=True, ccp_alpha=0.01, max_depth=10, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=1000
# [CV 1/10; 264/500] END bootstrap=True, ccp_alpha=0.01, max_depth=10, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=1000; neg_mean_absolute_error: (train=-7.871, test=-7.150) r2: (train=0.880, test=0.854) total time=   1.9s
# [CV 2/10; 264/500] START bootstrap=True, ccp_alpha=0.01, max_depth=10, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=1000
# [CV 2/10; 264/500] END bootstrap=True, ccp_alpha=0.01, max_depth=10, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=1000; neg_mean_absolute_error: (train=-7.542, test=-11.763) r2: (train=0.884, test=0.804) total time=   1.9s
# [CV 3/10; 264/500] START bootstrap=True, ccp_alpha=0.01, max_depth=10, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=1000
# [CV 3/10; 264/500] END bootstrap=True, ccp_alpha=0.01, max_depth=10, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=1000; neg_mean_absolute_error: (train=-6.904, test=-19.942) r2: (train=0.890, test=0.466) total time=   2.0s
# [CV 4/10; 264/500] START bootstrap=True, ccp_alpha=0.01, max_depth=10, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=1000
# [CV 4/10; 264/500] END bootstrap=True, ccp_alpha=0.01, max_depth=10, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=1000; neg_mean_absolute_error: (train=-7.367, test=-16.128) r2: (train=0.891, test=0.534) total time=   1.9s
# [CV 5/10; 264/500] START bootstrap=True, ccp_alpha=0.01, max_depth=10, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=1000
# [CV 5/10; 264/500] END bootstrap=True, ccp_alpha=0.01, max_depth=10, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=1000; neg_mean_absolute_error: (train=-7.642, test=-11.172) r2: (train=0.887, test=0.703) total time=   1.9s
# [CV 6/10; 264/500] START bootstrap=True, ccp_alpha=0.01, max_depth=10, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=1000
# [CV 6/10; 264/500] END bootstrap=True, ccp_alpha=0.01, max_depth=10, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=1000; neg_mean_absolute_error: (train=-7.440, test=-15.034) r2: (train=0.889, test=0.511) total time=   2.0s
# [CV 7/10; 264/500] START bootstrap=True, ccp_alpha=0.01, max_depth=10, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=1000
# [CV 7/10; 264/500] END bootstrap=True, ccp_alpha=0.01, max_depth=10, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=1000; neg_mean_absolute_error: (train=-7.172, test=-17.893) r2: (train=0.885, test=0.271) total time=   1.9s
# [CV 8/10; 264/500] START bootstrap=True, ccp_alpha=0.01, max_depth=10, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=1000
# [CV 8/10; 264/500] END bootstrap=True, ccp_alpha=0.01, max_depth=10, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=1000; neg_mean_absolute_error: (train=-7.584, test=-10.605) r2: (train=0.890, test=0.555) total time=   1.9s
# [CV 9/10; 264/500] START bootstrap=True, ccp_alpha=0.01, max_depth=10, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=1000
# [CV 9/10; 264/500] END bootstrap=True, ccp_alpha=0.01, max_depth=10, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=1000; neg_mean_absolute_error: (train=-7.334, test=-15.705) r2: (train=0.890, test=0.569) total time=   2.0s
# [CV 10/10; 264/500] START bootstrap=True, ccp_alpha=0.01, max_depth=10, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=1000
# [CV 10/10; 264/500] END bootstrap=True, ccp_alpha=0.01, max_depth=10, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=1000; neg_mean_absolute_error: (train=-7.525, test=-15.037) r2: (train=0.890, test=0.667) total time=   1.9s
# [CV 1/10; 265/500] START bootstrap=False, ccp_alpha=0.1, max_depth=11, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=800
# [CV 1/10; 265/500] END bootstrap=False, ccp_alpha=0.1, max_depth=11, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-11.908, test=-8.857) r2: (train=0.791, test=0.875) total time=   0.9s
# [CV 2/10; 265/500] START bootstrap=False, ccp_alpha=0.1, max_depth=11, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=800
# [CV 2/10; 265/500] END bootstrap=False, ccp_alpha=0.1, max_depth=11, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-11.820, test=-14.495) r2: (train=0.785, test=0.792) total time=   0.9s
# [CV 3/10; 265/500] START bootstrap=False, ccp_alpha=0.1, max_depth=11, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=800
# [CV 3/10; 265/500] END bootstrap=False, ccp_alpha=0.1, max_depth=11, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-10.913, test=-21.223) r2: (train=0.809, test=0.530) total time=   0.9s
# [CV 4/10; 265/500] START bootstrap=False, ccp_alpha=0.1, max_depth=11, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=800
# [CV 4/10; 265/500] END bootstrap=False, ccp_alpha=0.1, max_depth=11, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-11.376, test=-16.580) r2: (train=0.803, test=0.569) total time=   0.9s
# [CV 5/10; 265/500] START bootstrap=False, ccp_alpha=0.1, max_depth=11, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=800
# [CV 5/10; 265/500] END bootstrap=False, ccp_alpha=0.1, max_depth=11, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-11.761, test=-14.121) r2: (train=0.798, test=0.622) total time=   0.9s
# [CV 6/10; 265/500] START bootstrap=False, ccp_alpha=0.1, max_depth=11, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=800
# [CV 6/10; 265/500] END bootstrap=False, ccp_alpha=0.1, max_depth=11, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-11.961, test=-13.360) r2: (train=0.798, test=0.690) total time=   0.9s
# [CV 7/10; 265/500] START bootstrap=False, ccp_alpha=0.1, max_depth=11, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=800
# [CV 7/10; 265/500] END bootstrap=False, ccp_alpha=0.1, max_depth=11, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-11.052, test=-17.612) r2: (train=0.809, test=0.398) total time=   0.9s
# [CV 8/10; 265/500] START bootstrap=False, ccp_alpha=0.1, max_depth=11, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=800
# [CV 8/10; 265/500] END bootstrap=False, ccp_alpha=0.1, max_depth=11, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-11.463, test=-12.702) r2: (train=0.808, test=0.561) total time=   0.9s
# [CV 9/10; 265/500] START bootstrap=False, ccp_alpha=0.1, max_depth=11, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=800
# [CV 9/10; 265/500] END bootstrap=False, ccp_alpha=0.1, max_depth=11, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-11.086, test=-18.352) r2: (train=0.806, test=0.542) total time=   0.9s
# [CV 10/10; 265/500] START bootstrap=False, ccp_alpha=0.1, max_depth=11, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=800
# [CV 10/10; 265/500] END bootstrap=False, ccp_alpha=0.1, max_depth=11, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-11.701, test=-17.021) r2: (train=0.797, test=0.663) total time=   1.0s
# [CV 1/10; 266/500] START bootstrap=True, ccp_alpha=0.01, max_depth=None, max_features=0.4, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000
# [CV 1/10; 266/500] END bootstrap=True, ccp_alpha=0.01, max_depth=None, max_features=0.4, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-10.720, test=-7.601) r2: (train=0.805, test=0.855) total time=   1.7s
# [CV 2/10; 266/500] START bootstrap=True, ccp_alpha=0.01, max_depth=None, max_features=0.4, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000
# [CV 2/10; 266/500] END bootstrap=True, ccp_alpha=0.01, max_depth=None, max_features=0.4, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-10.652, test=-14.603) r2: (train=0.805, test=0.778) total time=   1.6s
# [CV 3/10; 266/500] START bootstrap=True, ccp_alpha=0.01, max_depth=None, max_features=0.4, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000
# [CV 3/10; 266/500] END bootstrap=True, ccp_alpha=0.01, max_depth=None, max_features=0.4, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-9.571, test=-21.071) r2: (train=0.821, test=0.510) total time=   1.7s
# [CV 4/10; 266/500] START bootstrap=True, ccp_alpha=0.01, max_depth=None, max_features=0.4, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000
# [CV 4/10; 266/500] END bootstrap=True, ccp_alpha=0.01, max_depth=None, max_features=0.4, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-10.166, test=-16.139) r2: (train=0.825, test=0.562) total time=   1.7s
# [CV 5/10; 266/500] START bootstrap=True, ccp_alpha=0.01, max_depth=None, max_features=0.4, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000
# [CV 5/10; 266/500] END bootstrap=True, ccp_alpha=0.01, max_depth=None, max_features=0.4, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-10.516, test=-11.202) r2: (train=0.816, test=0.724) total time=   1.6s
# [CV 6/10; 266/500] START bootstrap=True, ccp_alpha=0.01, max_depth=None, max_features=0.4, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000
# [CV 6/10; 266/500] END bootstrap=True, ccp_alpha=0.01, max_depth=None, max_features=0.4, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-10.456, test=-13.336) r2: (train=0.818, test=0.654) total time=   1.7s
# [CV 7/10; 266/500] START bootstrap=True, ccp_alpha=0.01, max_depth=None, max_features=0.4, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000
# [CV 7/10; 266/500] END bootstrap=True, ccp_alpha=0.01, max_depth=None, max_features=0.4, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-9.848, test=-17.873) r2: (train=0.820, test=0.331) total time=   2.7s
# [CV 8/10; 266/500] START bootstrap=True, ccp_alpha=0.01, max_depth=None, max_features=0.4, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000
# [CV 8/10; 266/500] END bootstrap=True, ccp_alpha=0.01, max_depth=None, max_features=0.4, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-10.296, test=-11.978) r2: (train=0.820, test=0.555) total time=   1.7s
# [CV 9/10; 266/500] START bootstrap=True, ccp_alpha=0.01, max_depth=None, max_features=0.4, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000
# [CV 9/10; 266/500] END bootstrap=True, ccp_alpha=0.01, max_depth=None, max_features=0.4, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-9.813, test=-17.904) r2: (train=0.823, test=0.529) total time=   1.6s
# [CV 10/10; 266/500] START bootstrap=True, ccp_alpha=0.01, max_depth=None, max_features=0.4, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000
# [CV 10/10; 266/500] END bootstrap=True, ccp_alpha=0.01, max_depth=None, max_features=0.4, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-10.414, test=-16.022) r2: (train=0.813, test=0.664) total time=   1.6s
# [CV 1/10; 267/500] START bootstrap=False, ccp_alpha=0, max_depth=5, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000
# [CV 1/10; 267/500] END bootstrap=False, ccp_alpha=0, max_depth=5, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-16.075, test=-11.891) r2: (train=0.684, test=0.839) total time=   1.0s
# [CV 2/10; 267/500] START bootstrap=False, ccp_alpha=0, max_depth=5, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000
# [CV 2/10; 267/500] END bootstrap=False, ccp_alpha=0, max_depth=5, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-15.489, test=-17.303) r2: (train=0.686, test=0.728) total time=   1.0s
# [CV 3/10; 267/500] START bootstrap=False, ccp_alpha=0, max_depth=5, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000
# [CV 3/10; 267/500] END bootstrap=False, ccp_alpha=0, max_depth=5, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-14.753, test=-22.695) r2: (train=0.715, test=0.515) total time=   1.0s
# [CV 4/10; 267/500] START bootstrap=False, ccp_alpha=0, max_depth=5, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000
# [CV 4/10; 267/500] END bootstrap=False, ccp_alpha=0, max_depth=5, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-15.087, test=-19.493) r2: (train=0.700, test=0.526) total time=   1.0s
# [CV 5/10; 267/500] START bootstrap=False, ccp_alpha=0, max_depth=5, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000
# [CV 5/10; 267/500] END bootstrap=False, ccp_alpha=0, max_depth=5, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-15.581, test=-16.185) r2: (train=0.701, test=0.585) total time=   1.0s
# [CV 6/10; 267/500] START bootstrap=False, ccp_alpha=0, max_depth=5, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000
# [CV 6/10; 267/500] END bootstrap=False, ccp_alpha=0, max_depth=5, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-16.031, test=-15.176) r2: (train=0.692, test=0.665) total time=   1.0s
# [CV 7/10; 267/500] START bootstrap=False, ccp_alpha=0, max_depth=5, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000
# [CV 7/10; 267/500] END bootstrap=False, ccp_alpha=0, max_depth=5, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-14.802, test=-19.709) r2: (train=0.714, test=0.344) total time=   1.0s
# [CV 8/10; 267/500] START bootstrap=False, ccp_alpha=0, max_depth=5, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000
# [CV 8/10; 267/500] END bootstrap=False, ccp_alpha=0, max_depth=5, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-15.498, test=-14.945) r2: (train=0.711, test=0.556) total time=   1.0s
# [CV 9/10; 267/500] START bootstrap=False, ccp_alpha=0, max_depth=5, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000
# [CV 9/10; 267/500] END bootstrap=False, ccp_alpha=0, max_depth=5, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-14.950, test=-21.152) r2: (train=0.708, test=0.487) total time=   1.1s
# [CV 10/10; 267/500] START bootstrap=False, ccp_alpha=0, max_depth=5, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000
# [CV 10/10; 267/500] END bootstrap=False, ccp_alpha=0, max_depth=5, max_features=log2, min_impurity_decrease=0.1, min_samples_leaf=3, n_estimators=1000; neg_mean_absolute_error: (train=-15.464, test=-17.977) r2: (train=0.699, test=0.660) total time=   1.0s
# [CV 1/10; 268/500] START bootstrap=False, ccp_alpha=0.05, max_depth=3, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=4, n_estimators=800
# [CV 1/10; 268/500] END bootstrap=False, ccp_alpha=0.05, max_depth=3, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=4, n_estimators=800; neg_mean_absolute_error: (train=-17.656, test=-13.846) r2: (train=0.624, test=0.790) total time=   0.9s
# [CV 2/10; 268/500] START bootstrap=False, ccp_alpha=0.05, max_depth=3, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=4, n_estimators=800
# [CV 2/10; 268/500] END bootstrap=False, ccp_alpha=0.05, max_depth=3, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=4, n_estimators=800; neg_mean_absolute_error: (train=-17.074, test=-17.844) r2: (train=0.631, test=0.697) total time=   0.9s
# [CV 3/10; 268/500] START bootstrap=False, ccp_alpha=0.05, max_depth=3, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=4, n_estimators=800
# [CV 3/10; 268/500] END bootstrap=False, ccp_alpha=0.05, max_depth=3, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=4, n_estimators=800; neg_mean_absolute_error: (train=-16.287, test=-23.025) r2: (train=0.660, test=0.492) total time=   0.9s
# [CV 4/10; 268/500] START bootstrap=False, ccp_alpha=0.05, max_depth=3, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=4, n_estimators=800
# [CV 4/10; 268/500] END bootstrap=False, ccp_alpha=0.05, max_depth=3, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=4, n_estimators=800; neg_mean_absolute_error: (train=-16.697, test=-21.066) r2: (train=0.643, test=0.504) total time=   0.8s
# [CV 5/10; 268/500] START bootstrap=False, ccp_alpha=0.05, max_depth=3, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=4, n_estimators=800
# [CV 5/10; 268/500] END bootstrap=False, ccp_alpha=0.05, max_depth=3, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=4, n_estimators=800; neg_mean_absolute_error: (train=-17.095, test=-16.340) r2: (train=0.647, test=0.593) total time=   0.9s
# [CV 6/10; 268/500] START bootstrap=False, ccp_alpha=0.05, max_depth=3, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=4, n_estimators=800
# [CV 6/10; 268/500] END bootstrap=False, ccp_alpha=0.05, max_depth=3, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=4, n_estimators=800; neg_mean_absolute_error: (train=-17.569, test=-16.957) r2: (train=0.639, test=0.629) total time=   0.9s
# [CV 7/10; 268/500] START bootstrap=False, ccp_alpha=0.05, max_depth=3, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=4, n_estimators=800
# [CV 7/10; 268/500] END bootstrap=False, ccp_alpha=0.05, max_depth=3, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=4, n_estimators=800; neg_mean_absolute_error: (train=-16.139, test=-21.484) r2: (train=0.662, test=0.248) total time=   0.9s
# [CV 8/10; 268/500] START bootstrap=False, ccp_alpha=0.05, max_depth=3, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=4, n_estimators=800
# [CV 8/10; 268/500] END bootstrap=False, ccp_alpha=0.05, max_depth=3, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=4, n_estimators=800; neg_mean_absolute_error: (train=-16.909, test=-16.715) r2: (train=0.658, test=0.535) total time=   0.9s
# [CV 9/10; 268/500] START bootstrap=False, ccp_alpha=0.05, max_depth=3, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=4, n_estimators=800
# [CV 9/10; 268/500] END bootstrap=False, ccp_alpha=0.05, max_depth=3, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=4, n_estimators=800; neg_mean_absolute_error: (train=-16.313, test=-22.947) r2: (train=0.659, test=0.440) total time=   0.9s
# [CV 10/10; 268/500] START bootstrap=False, ccp_alpha=0.05, max_depth=3, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=4, n_estimators=800
# [CV 10/10; 268/500] END bootstrap=False, ccp_alpha=0.05, max_depth=3, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=4, n_estimators=800; neg_mean_absolute_error: (train=-16.966, test=-16.767) r2: (train=0.644, test=0.671) total time=   0.9s
# [CV 1/10; 269/500] START bootstrap=False, ccp_alpha=0.1, max_depth=None, max_features=0.3, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 1/10; 269/500] END bootstrap=False, ccp_alpha=0.1, max_depth=None, max_features=0.3, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-0.642, test=-5.603) r2: (train=1.000, test=0.870) total time=   1.2s
# [CV 2/10; 269/500] START bootstrap=False, ccp_alpha=0.1, max_depth=None, max_features=0.3, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 2/10; 269/500] END bootstrap=False, ccp_alpha=0.1, max_depth=None, max_features=0.3, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-0.601, test=-7.371) r2: (train=1.000, test=0.857) total time=   1.1s
# [CV 3/10; 269/500] START bootstrap=False, ccp_alpha=0.1, max_depth=None, max_features=0.3, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 3/10; 269/500] END bootstrap=False, ccp_alpha=0.1, max_depth=None, max_features=0.3, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-0.629, test=-18.552) r2: (train=0.999, test=0.468) total time=   1.1s
# [CV 4/10; 269/500] START bootstrap=False, ccp_alpha=0.1, max_depth=None, max_features=0.3, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 4/10; 269/500] END bootstrap=False, ccp_alpha=0.1, max_depth=None, max_features=0.3, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-0.653, test=-16.340) r2: (train=0.999, test=0.466) total time=   1.1s
# [CV 5/10; 269/500] START bootstrap=False, ccp_alpha=0.1, max_depth=None, max_features=0.3, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 5/10; 269/500] END bootstrap=False, ccp_alpha=0.1, max_depth=None, max_features=0.3, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-0.643, test=-13.081) r2: (train=1.000, test=0.483) total time=   1.1s
# [CV 6/10; 269/500] START bootstrap=False, ccp_alpha=0.1, max_depth=None, max_features=0.3, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 6/10; 269/500] END bootstrap=False, ccp_alpha=0.1, max_depth=None, max_features=0.3, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-0.625, test=-14.765) r2: (train=1.000, test=0.435) total time=   1.2s
# [CV 7/10; 269/500] START bootstrap=False, ccp_alpha=0.1, max_depth=None, max_features=0.3, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 7/10; 269/500] END bootstrap=False, ccp_alpha=0.1, max_depth=None, max_features=0.3, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-0.621, test=-18.495) r2: (train=1.000, test=0.141) total time=   1.1s
# [CV 8/10; 269/500] START bootstrap=False, ccp_alpha=0.1, max_depth=None, max_features=0.3, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 8/10; 269/500] END bootstrap=False, ccp_alpha=0.1, max_depth=None, max_features=0.3, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-0.598, test=-9.434) r2: (train=1.000, test=0.591) total time=   1.1s
# [CV 9/10; 269/500] START bootstrap=False, ccp_alpha=0.1, max_depth=None, max_features=0.3, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800
# [CV 9/10; 269/500] END bootstrap=False, ccp_alpha=0.1, max_depth=None, max_features=0.3, min_impurity_decrease=0.05, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-0.597, test=-13.051) r2: (train=1.000, test=0.665) total time=   1.2s
# ...
# [CV 1/10; 499/500] START bootstrap=True, ccp_alpha=0, max_depth=5, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 1/10; 499/500] END bootstrap=True, ccp_alpha=0, max_depth=5, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-13.668, test=-10.010) r2: (train=0.737, test=0.842) total time=   1.2s
# [CV 2/10; 499/500] START bootstrap=True, ccp_alpha=0, max_depth=5, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 2/10; 499/500] END bootstrap=True, ccp_alpha=0, max_depth=5, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-13.174, test=-15.446) r2: (train=0.743, test=0.757) total time=   1.2s
# [CV 3/10; 499/500] START bootstrap=True, ccp_alpha=0, max_depth=5, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 3/10; 499/500] END bootstrap=True, ccp_alpha=0, max_depth=5, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-12.447, test=-21.128) r2: (train=0.770, test=0.510) total time=   1.2s
# [CV 4/10; 499/500] START bootstrap=True, ccp_alpha=0, max_depth=5, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 4/10; 499/500] END bootstrap=True, ccp_alpha=0, max_depth=5, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-12.965, test=-17.300) r2: (train=0.750, test=0.573) total time=   1.2s
# [CV 5/10; 499/500] START bootstrap=True, ccp_alpha=0, max_depth=5, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 5/10; 499/500] END bootstrap=True, ccp_alpha=0, max_depth=5, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-13.295, test=-13.586) r2: (train=0.748, test=0.683) total time=   1.2s
# [CV 6/10; 499/500] START bootstrap=True, ccp_alpha=0, max_depth=5, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 6/10; 499/500] END bootstrap=True, ccp_alpha=0, max_depth=5, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-13.558, test=-14.788) r2: (train=0.747, test=0.668) total time=   1.2s
# [CV 7/10; 499/500] START bootstrap=True, ccp_alpha=0, max_depth=5, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 7/10; 499/500] END bootstrap=True, ccp_alpha=0, max_depth=5, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-12.297, test=-21.021) r2: (train=0.768, test=0.254) total time=   1.2s
# [CV 8/10; 499/500] START bootstrap=True, ccp_alpha=0, max_depth=5, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 8/10; 499/500] END bootstrap=True, ccp_alpha=0, max_depth=5, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-13.151, test=-13.649) r2: (train=0.764, test=0.548) total time=   1.2s
# [CV 9/10; 499/500] START bootstrap=True, ccp_alpha=0, max_depth=5, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 9/10; 499/500] END bootstrap=True, ccp_alpha=0, max_depth=5, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-12.631, test=-19.495) r2: (train=0.758, test=0.505) total time=   1.2s
# [CV 10/10; 499/500] START bootstrap=True, ccp_alpha=0, max_depth=5, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 10/10; 499/500] END bootstrap=True, ccp_alpha=0, max_depth=5, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-13.137, test=-16.083) r2: (train=0.755, test=0.676) total time=   1.2s
# [CV 1/10; 500/500] START bootstrap=False, ccp_alpha=0, max_depth=3, max_features=0.6, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 1/10; 500/500] END bootstrap=False, ccp_alpha=0, max_depth=3, max_features=0.6, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-16.279, test=-13.709) r2: (train=0.644, test=0.762) total time=   0.9s
# [CV 2/10; 500/500] START bootstrap=False, ccp_alpha=0, max_depth=3, max_features=0.6, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 2/10; 500/500] END bootstrap=False, ccp_alpha=0, max_depth=3, max_features=0.6, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-16.276, test=-18.277) r2: (train=0.639, test=0.650) total time=   0.9s
# [CV 3/10; 500/500] START bootstrap=False, ccp_alpha=0, max_depth=3, max_features=0.6, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 3/10; 500/500] END bootstrap=False, ccp_alpha=0, max_depth=3, max_features=0.6, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-15.166, test=-22.297) r2: (train=0.674, test=0.474) total time=   0.9s
# [CV 4/10; 500/500] START bootstrap=False, ccp_alpha=0, max_depth=3, max_features=0.6, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 4/10; 500/500] END bootstrap=False, ccp_alpha=0, max_depth=3, max_features=0.6, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-15.064, test=-19.778) r2: (train=0.672, test=0.535) total time=   0.9s
# [CV 5/10; 500/500] START bootstrap=False, ccp_alpha=0, max_depth=3, max_features=0.6, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 5/10; 500/500] END bootstrap=False, ccp_alpha=0, max_depth=3, max_features=0.6, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-15.985, test=-16.721) r2: (train=0.657, test=0.533) total time=   0.9s
# [CV 6/10; 500/500] START bootstrap=False, ccp_alpha=0, max_depth=3, max_features=0.6, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 6/10; 500/500] END bootstrap=False, ccp_alpha=0, max_depth=3, max_features=0.6, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-16.768, test=-17.142) r2: (train=0.642, test=0.630) total time=   0.9s
# [CV 7/10; 500/500] START bootstrap=False, ccp_alpha=0, max_depth=3, max_features=0.6, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 7/10; 500/500] END bootstrap=False, ccp_alpha=0, max_depth=3, max_features=0.6, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-14.805, test=-21.517) r2: (train=0.678, test=0.217) total time=   1.0s
# [CV 8/10; 500/500] START bootstrap=False, ccp_alpha=0, max_depth=3, max_features=0.6, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 8/10; 500/500] END bootstrap=False, ccp_alpha=0, max_depth=3, max_features=0.6, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-15.972, test=-15.057) r2: (train=0.668, test=0.543) total time=   0.9s
# [CV 9/10; 500/500] START bootstrap=False, ccp_alpha=0, max_depth=3, max_features=0.6, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 9/10; 500/500] END bootstrap=False, ccp_alpha=0, max_depth=3, max_features=0.6, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-15.125, test=-22.240) r2: (train=0.674, test=0.412) total time=   0.9s
# [CV 10/10; 500/500] START bootstrap=False, ccp_alpha=0, max_depth=3, max_features=0.6, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 10/10; 500/500] END bootstrap=False, ccp_alpha=0, max_depth=3, max_features=0.6, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-16.181, test=-14.519) r2: (train=0.651, test=0.691) total time=   0.9s
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         1.142080      0.021026         0.093112        0.014312
# 1         1.386218      0.018102         0.112640        0.007987
# 2         1.262291      0.115310         0.093161        0.012139
# 3         1.495280      0.229076         0.116212        0.009743
# 4         1.486561      0.218673         0.102347        0.019527
# ..             ...           ...              ...             ...
# 495       0.783013      0.028390         0.094614        0.013799
# 496       1.360775      0.015189         0.114232        0.012806
# 497       1.455846      0.228661         0.120286        0.015683
# 498       1.093950      0.013591         0.092602        0.010471
# 499       0.805394      0.024719         0.097565        0.012900
#
#     param_n_estimators param_min_samples_leaf param_min_impurity_decrease  \
# 0                  800                      4                        0.05
# 1                 1000                      1                           0
# 2                  800                      3                           0
# 3                 1000                      2                        0.05
# 4                  800                      2                           0
# ..                 ...                    ...                         ...
# 495                800                      2                        0.01
# 496               1000                      1                         0.1
# 497               1000                      4                         0.1
# 498                800                      2                           0
# 499                800                      2                           0
#
#     param_max_features param_max_depth param_ccp_alpha  ...  \
# 0                  0.6               5               0  ...
# 1                  0.4               5               0  ...
# 2                  0.3              11            0.05  ...
# 3                  0.3              10               0  ...
# 4                 None              12            0.01  ...
# ..                 ...             ...             ...  ...
# 495               log2              10               0  ...
# 496               log2               3            0.05  ...
# 497               log2               4            0.01  ...
# 498                0.3               5               0  ...
# 499                0.6               3               0  ...
#
#     split2_train_neg_mean_absolute_error split3_train_neg_mean_absolute_error  \
# 0                             -12.784480                           -13.367926
# 1                             -11.323522                           -11.932866
# 2                             -10.224475                           -10.753490
# 3                              -8.584300                            -8.931030
# 4                              -5.101264                            -5.343437
# ..                                   ...                                  ...
# 495                            -9.278215                            -9.507404
# 496                           -18.320082                           -18.703794
# 497                           -17.732449                           -18.149782
# 498                           -12.447254                           -12.965254
# 499                           -15.165831                           -15.063802
#
#      split4_train_neg_mean_absolute_error  \
# 0                              -13.519418
# 1                              -12.153859
# 2                              -11.199422
# 3                               -9.340774
# 4                               -5.224364
# ..                                    ...
# 495                             -9.737196
# 496                            -19.353411
# 497                            -18.697742
# 498                            -13.294772
# 499                            -15.984646
#
#      split5_train_neg_mean_absolute_error  \
# 0                              -13.706475
# 1                              -12.520475
# 2                              -10.988082
# 3                               -9.321063
# 4                               -4.680148
# ..                                    ...
# 495                             -9.961462
# 496                            -19.325872
# 497                            -18.965340
# 498                            -13.557528
# 499                            -16.768414
#
#      split6_train_neg_mean_absolute_error  \
# 0                              -12.709251
# 1                              -11.082874
# 2                              -10.267923
# 3                               -8.650025
# 4                               -4.765500
# ..                                    ...
# 495                             -9.245816
# 496                            -18.514200
# 497                            -17.974091
# 498                            -12.297151
# 499                            -14.805341
#
#      split7_train_neg_mean_absolute_error  \
# 0                              -13.420868
# 1                              -11.951267
# 2                              -10.892861
# 3                               -9.147263
# 4                               -4.545679
# ..                                    ...
# 495                             -9.386174
# 496                            -19.082977
# 497                            -18.401574
# 498                            -13.151066
# 499                            -15.972128
#
#      split8_train_neg_mean_absolute_error  \
# 0                              -12.818032
# 1                              -11.434614
# 2                              -10.289829
# 3                               -8.865181
# 4                               -4.716160
# ..                                    ...
# 495                             -9.132404
# 496                            -18.468867
# 497                            -17.607401
# 498                            -12.631101
# 499                            -15.125186
#
#      split9_train_neg_mean_absolute_error  mean_train_neg_mean_absolute_error  \
# 0                              -13.526854                          -13.298940
# 1                              -11.930832                          -11.877738
# 2                              -10.873268                          -10.795214
# 3                               -9.014577                           -9.081231
# 4                               -4.337199                           -4.877992
# ..                                    ...                                 ...
# 495                             -9.432193                           -9.537988
# 496                            -19.069045                          -18.991396
# 497                            -18.412224                          -18.351442
# 498                            -13.137300                          -13.032279
# 499                            -16.180875                          -15.762100
#
#      std_train_neg_mean_absolute_error
# 0                             0.367932
# 1                             0.456027
# 2                             0.381931
# 3                             0.312555
# 4                             0.319612
# ..                                 ...
# 495                           0.278901
# 496                           0.482912
# 497                           0.487123
# 498                           0.429138
# 499                           0.630630
#
# [500 rows x 62 columns]
# {'n_estimators': 800, 'min_samples_leaf': 2, 'min_impurity_decrease': 0, 'max_features': 'log2', 'max_depth': None, 'ccp_alpha': 0, 'bootstrap': False}

# %%
from google.colab import files

gd_mi = pd.DataFrame(grid_search.cv_results_)
gd_mi.to_csv('grid_search_mi.csv', encoding = 'utf-8-sig') 
files.download('grid_search_mi.csv')

# %% [markdown]
# GridSearchCV, no log-transform

# %%
rf = RandomForestRegressor()

#Metrics for Evualation:
met_grid= ['r2', 'neg_mean_absolute_error'] #The metric codes from sklearn

# Create the parameter grid based on the results of random search 
params = {
          'max_depth': [7,10,13],
          'max_features': ['sqrt', 0.2, 0.3, 0.5, None],
          'n_estimators': [800],
          'min_samples_leaf' : [1,2,3],
          'bootstrap' : [True],
          'min_impurity_decrease' : [0, 0.01],
          'ccp_alpha' : [0, 0.01]
      }

# Instantiate the grid search model
grid_search = GridSearchCV(estimator = rf, param_grid = params, scoring = met_grid, refit = 'r2',
                                cv = 10, n_jobs = 1, verbose = 10, return_train_score = True)
# Fit the grid search to the data
grid_search.fit(X_TV, Y_TV)

print(pd.DataFrame(grid_search.cv_results_))
print(grid_search.best_params_)

from google.colab import files

gd_w = pd.DataFrame(grid_search.cv_results_)
gd_w.to_csv('grid_search_w6.csv', encoding = 'utf-8-sig') 
files.download('grid_search_w6.csv')
# Out:
# Fitting 10 folds for each of 180 candidates, totalling 1800 fits
# [CV 1/10; 1/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800
# [CV 1/10; 1/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.813, test=-8.858) r2: (train=0.761, test=0.145) total time=   1.8s
# [CV 2/10; 1/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800
# [CV 2/10; 1/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.969, test=-8.157) r2: (train=0.736, test=0.453) total time=   1.9s
# [CV 3/10; 1/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800
# [CV 3/10; 1/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-6.183, test=-6.549) r2: (train=0.734, test=0.623) total time=   1.2s
# [CV 4/10; 1/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800
# [CV 4/10; 1/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-6.043, test=-8.237) r2: (train=0.734, test=0.512) total time=   1.1s
# [CV 5/10; 1/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800
# [CV 5/10; 1/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-6.158, test=-8.439) r2: (train=0.730, test=0.496) total time=   1.0s
# [CV 6/10; 1/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800
# [CV 6/10; 1/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.951, test=-8.533) r2: (train=0.738, test=0.452) total time=   1.1s
# [CV 7/10; 1/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800
# [CV 7/10; 1/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-6.232, test=-7.453) r2: (train=0.730, test=0.555) total time=   1.1s
# [CV 8/10; 1/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800
# [CV 8/10; 1/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.618, test=-11.755) r2: (train=0.750, test=0.347) total time=   1.1s
# [CV 9/10; 1/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800
# [CV 9/10; 1/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.978, test=-9.005) r2: (train=0.744, test=0.343) total time=   1.1s
# [CV 10/10; 1/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800
# [CV 10/10; 1/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.879, test=-8.682) r2: (train=0.748, test=0.454) total time=   1.1s
# [CV 1/10; 2/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 1/10; 2/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-6.897, test=-8.788) r2: (train=0.661, test=0.174) total time=   1.0s
# [CV 2/10; 2/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 2/10; 2/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-7.091, test=-8.574) r2: (train=0.635, test=0.410) total time=   1.0s
# [CV 3/10; 2/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 3/10; 2/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-7.228, test=-6.993) r2: (train=0.630, test=0.557) total time=   1.0s
# [CV 4/10; 2/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 4/10; 2/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-7.072, test=-8.469) r2: (train=0.634, test=0.495) total time=   1.0s
# [CV 5/10; 2/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 5/10; 2/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-7.142, test=-8.667) r2: (train=0.639, test=0.480) total time=   1.0s
# [CV 6/10; 2/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 6/10; 2/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-6.899, test=-8.769) r2: (train=0.642, test=0.441) total time=   1.0s
# [CV 7/10; 2/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 7/10; 2/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-7.289, test=-7.731) r2: (train=0.633, test=0.562) total time=   1.0s
# [CV 8/10; 2/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 8/10; 2/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-6.574, test=-12.264) r2: (train=0.650, test=0.328) total time=   1.0s
# [CV 9/10; 2/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 9/10; 2/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-7.038, test=-9.148) r2: (train=0.641, test=0.330) total time=   1.0s
# [CV 10/10; 2/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 10/10; 2/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-7.044, test=-9.048) r2: (train=0.638, test=0.374) total time=   1.0s
# [CV 1/10; 3/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800
# [CV 1/10; 3/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.557, test=-8.819) r2: (train=0.598, test=0.181) total time=   1.0s
# [CV 2/10; 3/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800
# [CV 2/10; 3/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.637, test=-8.807) r2: (train=0.575, test=0.376) total time=   1.0s
# [CV 3/10; 3/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800
# [CV 3/10; 3/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.836, test=-7.415) r2: (train=0.570, test=0.474) total time=   1.0s
# [CV 4/10; 3/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800
# [CV 4/10; 3/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.828, test=-8.806) r2: (train=0.566, test=0.471) total time=   1.0s
# [CV 5/10; 3/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800
# [CV 5/10; 3/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.868, test=-9.019) r2: (train=0.565, test=0.459) total time=   1.0s
# [CV 6/10; 3/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800
# [CV 6/10; 3/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.575, test=-9.244) r2: (train=0.576, test=0.409) total time=   1.0s
# [CV 7/10; 3/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800
# [CV 7/10; 3/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.911, test=-8.146) r2: (train=0.570, test=0.520) total time=   1.0s
# [CV 8/10; 3/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800
# [CV 8/10; 3/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.289, test=-12.733) r2: (train=0.579, test=0.302) total time=   1.0s
# [CV 9/10; 3/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800
# [CV 9/10; 3/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.682, test=-9.417) r2: (train=0.579, test=0.324) total time=   1.0s
# [CV 10/10; 3/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800
# [CV 10/10; 3/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.706, test=-9.332) r2: (train=0.578, test=0.313) total time=   1.0s
# [CV 1/10; 4/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800
# [CV 1/10; 4/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.838, test=-8.687) r2: (train=0.761, test=0.173) total time=   1.0s
# [CV 2/10; 4/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800
# [CV 2/10; 4/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-6.027, test=-8.011) r2: (train=0.734, test=0.463) total time=   1.0s
# [CV 3/10; 4/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800
# [CV 3/10; 4/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-6.242, test=-6.458) r2: (train=0.728, test=0.636) total time=   1.1s
# [CV 4/10; 4/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800
# [CV 4/10; 4/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-6.063, test=-8.423) r2: (train=0.737, test=0.486) total time=   1.0s
# [CV 5/10; 4/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800
# [CV 5/10; 4/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-6.221, test=-8.547) r2: (train=0.724, test=0.482) total time=   1.0s
# [CV 6/10; 4/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800
# [CV 6/10; 4/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.953, test=-8.526) r2: (train=0.743, test=0.455) total time=   1.0s
# [CV 7/10; 4/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800
# [CV 7/10; 4/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-6.318, test=-7.684) r2: (train=0.722, test=0.556) total time=   1.0s
# [CV 8/10; 4/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800
# [CV 8/10; 4/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.729, test=-11.648) r2: (train=0.743, test=0.358) total time=   1.0s
# [CV 9/10; 4/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800
# [CV 9/10; 4/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-6.134, test=-8.932) r2: (train=0.733, test=0.357) total time=   1.0s
# [CV 10/10; 4/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800
# [CV 10/10; 4/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.898, test=-8.586) r2: (train=0.746, test=0.474) total time=   1.1s
# [CV 1/10; 5/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 1/10; 5/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-6.897, test=-8.751) r2: (train=0.661, test=0.176) total time=   1.0s
# [CV 2/10; 5/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 2/10; 5/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-7.108, test=-8.554) r2: (train=0.633, test=0.409) total time=   1.1s
# [CV 3/10; 5/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 3/10; 5/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-7.290, test=-7.010) r2: (train=0.627, test=0.563) total time=   1.0s
# [CV 4/10; 5/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 4/10; 5/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-7.053, test=-8.403) r2: (train=0.636, test=0.500) total time=   1.0s
# [CV 5/10; 5/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 5/10; 5/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-7.224, test=-8.669) r2: (train=0.631, test=0.476) total time=   1.0s
# [CV 6/10; 5/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 6/10; 5/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-7.002, test=-8.794) r2: (train=0.639, test=0.441) total time=   1.1s
# [CV 7/10; 5/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 7/10; 5/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-7.388, test=-7.683) r2: (train=0.625, test=0.568) total time=   1.0s
# [CV 8/10; 5/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 8/10; 5/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-6.639, test=-12.214) r2: (train=0.647, test=0.334) total time=   1.0s
# [CV 9/10; 5/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 9/10; 5/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-7.037, test=-9.165) r2: (train=0.642, test=0.333) total time=   1.0s
# [CV 10/10; 5/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 10/10; 5/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-7.004, test=-8.872) r2: (train=0.642, test=0.392) total time=   1.0s
# [CV 1/10; 6/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 1/10; 6/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.549, test=-8.791) r2: (train=0.597, test=0.184) total time=   1.0s
# [CV 2/10; 6/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 2/10; 6/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.728, test=-9.000) r2: (train=0.570, test=0.363) total time=   1.0s
# [CV 3/10; 6/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 3/10; 6/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.916, test=-7.482) r2: (train=0.566, test=0.478) total time=   1.0s
# [CV 4/10; 6/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 4/10; 6/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.893, test=-8.948) r2: (train=0.555, test=0.452) total time=   1.0s
# [CV 5/10; 6/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 5/10; 6/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.837, test=-8.991) r2: (train=0.566, test=0.460) total time=   1.0s
# [CV 6/10; 6/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 6/10; 6/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.656, test=-9.312) r2: (train=0.574, test=0.409) total time=   1.0s
# [CV 7/10; 6/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 7/10; 6/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.995, test=-8.201) r2: (train=0.562, test=0.513) total time=   1.0s
# [CV 8/10; 6/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 8/10; 6/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.356, test=-12.664) r2: (train=0.575, test=0.311) total time=   1.0s
# [CV 9/10; 6/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 9/10; 6/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.685, test=-9.355) r2: (train=0.582, test=0.333) total time=   1.0s
# [CV 10/10; 6/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 10/10; 6/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=sqrt, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.765, test=-9.335) r2: (train=0.573, test=0.305) total time=   1.0s
# [CV 1/10; 7/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800
# [CV 1/10; 7/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.405, test=-8.531) r2: (train=0.786, test=0.155) total time=   1.1s
# [CV 2/10; 7/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800
# [CV 2/10; 7/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.636, test=-7.844) r2: (train=0.760, test=0.477) total time=   1.1s
# [CV 3/10; 7/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800
# [CV 3/10; 7/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.847, test=-6.188) r2: (train=0.753, test=0.655) total time=   1.1s
# [CV 4/10; 7/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800
# [CV 4/10; 7/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.658, test=-8.050) r2: (train=0.760, test=0.512) total time=   1.1s
# [CV 5/10; 7/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800
# [CV 5/10; 7/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.748, test=-8.249) r2: (train=0.756, test=0.501) total time=   1.1s
# [CV 6/10; 7/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800
# [CV 6/10; 7/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.513, test=-8.141) r2: (train=0.768, test=0.477) total time=   1.1s
# [CV 7/10; 7/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800
# [CV 7/10; 7/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.914, test=-7.343) r2: (train=0.745, test=0.557) total time=   1.1s
# [CV 8/10; 7/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800
# [CV 8/10; 7/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.291, test=-11.506) r2: (train=0.771, test=0.367) total time=   1.1s
# [CV 9/10; 7/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800
# [CV 9/10; 7/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.572, test=-8.934) r2: (train=0.768, test=0.351) total time=   1.1s
# [CV 10/10; 7/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800
# [CV 10/10; 7/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.497, test=-8.297) r2: (train=0.769, test=0.507) total time=   1.1s
# [CV 1/10; 8/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 1/10; 8/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-6.334, test=-8.471) r2: (train=0.700, test=0.173) total time=   1.0s
# [CV 2/10; 8/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 2/10; 8/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-6.462, test=-8.106) r2: (train=0.680, test=0.444) total time=   1.0s
# [CV 3/10; 8/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 3/10; 8/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-6.734, test=-6.769) r2: (train=0.669, test=0.572) total time=   1.1s
# [CV 4/10; 8/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 4/10; 8/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-6.532, test=-8.146) r2: (train=0.678, test=0.524) total time=   1.0s
# [CV 5/10; 8/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 5/10; 8/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-6.612, test=-8.261) r2: (train=0.676, test=0.499) total time=   1.1s
# [CV 6/10; 8/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 6/10; 8/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-6.412, test=-8.447) r2: (train=0.684, test=0.453) total time=   1.1s
# [CV 7/10; 8/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 7/10; 8/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-6.731, test=-7.410) r2: (train=0.671, test=0.577) total time=   1.0s
# [CV 8/10; 8/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 8/10; 8/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-6.136, test=-12.004) r2: (train=0.684, test=0.334) total time=   1.1s
# [CV 9/10; 8/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 9/10; 8/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-6.560, test=-9.318) r2: (train=0.679, test=0.319) total time=   1.0s
# [CV 10/10; 8/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800
# [CV 10/10; 8/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-6.414, test=-8.633) r2: (train=0.683, test=0.408) total time=   1.1s
# [CV 1/10; 9/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800
# [CV 1/10; 9/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-6.911, test=-8.414) r2: (train=0.642, test=0.186) total time=   1.0s
# [CV 2/10; 9/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800
# [CV 2/10; 9/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.082, test=-8.668) r2: (train=0.616, test=0.382) total time=   1.0s
# [CV 3/10; 9/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800
# [CV 3/10; 9/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.359, test=-7.050) r2: (train=0.608, test=0.505) total time=   1.0s
# [CV 4/10; 9/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800
# [CV 4/10; 9/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.243, test=-8.300) r2: (train=0.610, test=0.512) total time=   1.0s
# [CV 5/10; 9/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800
# [CV 5/10; 9/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.271, test=-8.549) r2: (train=0.614, test=0.478) total time=   1.0s
# [CV 6/10; 9/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800
# [CV 6/10; 9/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.049, test=-8.736) r2: (train=0.619, test=0.431) total time=   1.0s
# [CV 7/10; 9/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800
# [CV 7/10; 9/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.458, test=-7.938) r2: (train=0.602, test=0.544) total time=   1.0s
# [CV 8/10; 9/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800
# [CV 8/10; 9/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-6.741, test=-12.341) r2: (train=0.627, test=0.328) total time=   1.0s
# [CV 9/10; 9/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800
# [CV 9/10; 9/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.045, test=-9.432) r2: (train=0.626, test=0.322) total time=   1.1s
# [CV 10/10; 9/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800
# [CV 10/10; 9/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.142, test=-9.022) r2: (train=0.616, test=0.332) total time=   1.1s
# [CV 1/10; 10/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800
# [CV 1/10; 10/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.447, test=-8.599) r2: (train=0.784, test=0.150) total time=   1.0s
# [CV 2/10; 10/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800
# [CV 2/10; 10/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.691, test=-7.927) r2: (train=0.758, test=0.467) total time=   1.1s
# [CV 3/10; 10/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800
# [CV 3/10; 10/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.895, test=-6.273) r2: (train=0.753, test=0.647) total time=   1.1s
# [CV 4/10; 10/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800
# [CV 4/10; 10/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.703, test=-8.203) r2: (train=0.758, test=0.510) total time=   1.1s
# [CV 5/10; 10/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800
# [CV 5/10; 10/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.876, test=-8.245) r2: (train=0.750, test=0.489) total time=   1.1s
# [CV 6/10; 10/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800
# [CV 6/10; 10/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.588, test=-8.158) r2: (train=0.761, test=0.470) total time=   1.1s
# [CV 7/10; 10/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800
# [CV 7/10; 10/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.908, test=-7.328) r2: (train=0.748, test=0.567) total time=   1.1s
# [CV 8/10; 10/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800
# [CV 8/10; 10/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.375, test=-11.606) r2: (train=0.767, test=0.362) total time=   1.1s
# [CV 9/10; 10/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800
# [CV 9/10; 10/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.596, test=-8.946) r2: (train=0.767, test=0.347) total time=   1.1s
# [CV 10/10; 10/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800
# [CV 10/10; 10/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-5.467, test=-8.426) r2: (train=0.771, test=0.479) total time=   1.1s
# [CV 1/10; 11/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 1/10; 11/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-6.302, test=-8.386) r2: (train=0.703, test=0.180) total time=   1.0s
# [CV 2/10; 11/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 2/10; 11/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-6.558, test=-8.393) r2: (train=0.673, test=0.418) total time=   1.0s
# [CV 3/10; 11/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 3/10; 11/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-6.691, test=-6.639) r2: (train=0.669, test=0.573) total time=   1.0s
# [CV 4/10; 11/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 4/10; 11/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-6.624, test=-8.125) r2: (train=0.667, test=0.521) total time=   1.0s
# [CV 5/10; 11/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 5/10; 11/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-6.637, test=-8.230) r2: (train=0.673, test=0.499) total time=   1.0s
# [CV 6/10; 11/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 6/10; 11/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-6.415, test=-8.305) r2: (train=0.684, test=0.466) total time=   1.0s
# [CV 7/10; 11/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 7/10; 11/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-6.794, test=-7.439) r2: (train=0.665, test=0.578) total time=   1.0s
# [CV 8/10; 11/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 8/10; 11/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-6.167, test=-11.811) r2: (train=0.679, test=0.359) total time=   1.0s
# [CV 9/10; 11/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 9/10; 11/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-6.529, test=-9.282) r2: (train=0.680, test=0.318) total time=   1.0s
# [CV 10/10; 11/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 10/10; 11/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-6.453, test=-8.646) r2: (train=0.682, test=0.417) total time=   1.0s
# [CV 1/10; 12/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 1/10; 12/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-6.888, test=-8.383) r2: (train=0.644, test=0.179) total time=   1.0s
# [CV 2/10; 12/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 2/10; 12/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.103, test=-8.470) r2: (train=0.614, test=0.404) total time=   1.0s
# [CV 3/10; 12/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 3/10; 12/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.409, test=-7.157) r2: (train=0.608, test=0.501) total time=   1.0s
# [CV 4/10; 12/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 4/10; 12/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.229, test=-8.366) r2: (train=0.614, test=0.505) total time=   1.0s
# [CV 5/10; 12/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 5/10; 12/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.294, test=-8.685) r2: (train=0.613, test=0.472) total time=   1.0s
# [CV 6/10; 12/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 6/10; 12/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.150, test=-8.816) r2: (train=0.610, test=0.428) total time=   1.0s
# [CV 7/10; 12/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 7/10; 12/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.441, test=-7.882) r2: (train=0.604, test=0.548) total time=   1.0s
# [CV 8/10; 12/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 8/10; 12/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-6.697, test=-12.366) r2: (train=0.625, test=0.319) total time=   1.0s
# [CV 9/10; 12/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 9/10; 12/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.095, test=-9.568) r2: (train=0.624, test=0.308) total time=   1.0s
# [CV 10/10; 12/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 10/10; 12/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.2, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-7.129, test=-9.036) r2: (train=0.618, test=0.340) total time=   1.0s
# [CV 1/10; 13/180] START bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800
# [CV 1/10; 13/180] END bootstrap=True, ccp_alpha=0, max_depth=7, max_features=0.3, min_impurity_decrease=0, min_samples_leaf=1, n_estimators=800; neg_mean_absolute_error: (train=-4.972, test=-8.565) r2: (train=0.815, test=0.111) total time=   1.1s
# ...
# [CV 1/10; 179/180] END bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-3.553, test=-7.814) r2: (train=0.878, test=0.030) total time=   1.5s
# [CV 2/10; 179/180] START bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 2/10; 179/180] END bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-3.860, test=-6.939) r2: (train=0.850, test=0.525) total time=   1.4s
# [CV 3/10; 179/180] START bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 3/10; 179/180] END bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-3.940, test=-5.189) r2: (train=0.855, test=0.663) total time=   1.4s
# [CV 4/10; 179/180] START bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 4/10; 179/180] END bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-3.735, test=-6.849) r2: (train=0.867, test=0.565) total time=   1.4s
# [CV 5/10; 179/180] START bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 5/10; 179/180] END bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-3.716, test=-7.175) r2: (train=0.865, test=0.515) total time=   1.4s
# [CV 6/10; 179/180] START bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 6/10; 179/180] END bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-3.850, test=-7.423) r2: (train=0.856, test=0.501) total time=   1.5s
# [CV 7/10; 179/180] START bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 7/10; 179/180] END bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-3.978, test=-6.804) r2: (train=0.856, test=0.516) total time=   1.4s
# [CV 8/10; 179/180] START bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 8/10; 179/180] END bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-3.626, test=-12.289) r2: (train=0.859, test=0.240) total time=   1.4s
# [CV 9/10; 179/180] START bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 9/10; 179/180] END bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-3.800, test=-9.444) r2: (train=0.853, test=0.265) total time=   1.4s
# [CV 10/10; 179/180] START bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800
# [CV 10/10; 179/180] END bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=2, n_estimators=800; neg_mean_absolute_error: (train=-3.882, test=-7.796) r2: (train=0.852, test=0.476) total time=   1.4s
# [CV 1/10; 180/180] START bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 1/10; 180/180] END bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-4.508, test=-7.821) r2: (train=0.817, test=0.036) total time=   1.4s
# [CV 2/10; 180/180] START bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 2/10; 180/180] END bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-4.765, test=-7.266) r2: (train=0.783, test=0.481) total time=   1.4s
# [CV 3/10; 180/180] START bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 3/10; 180/180] END bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-4.886, test=-5.884) r2: (train=0.784, test=0.578) total time=   1.4s
# [CV 4/10; 180/180] START bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 4/10; 180/180] END bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-4.766, test=-7.039) r2: (train=0.793, test=0.572) total time=   1.4s
# [CV 5/10; 180/180] START bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 5/10; 180/180] END bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-4.656, test=-7.200) r2: (train=0.794, test=0.526) total time=   1.4s
# [CV 6/10; 180/180] START bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 6/10; 180/180] END bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-4.812, test=-7.771) r2: (train=0.781, test=0.461) total time=   1.4s
# [CV 7/10; 180/180] START bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 7/10; 180/180] END bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-4.841, test=-6.995) r2: (train=0.793, test=0.472) total time=   1.4s
# [CV 8/10; 180/180] START bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 8/10; 180/180] END bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-4.400, test=-12.425) r2: (train=0.803, test=0.250) total time=   1.4s
# [CV 9/10; 180/180] START bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 9/10; 180/180] END bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-4.618, test=-9.738) r2: (train=0.787, test=0.234) total time=   1.4s
# [CV 10/10; 180/180] START bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800
# [CV 10/10; 180/180] END bootstrap=True, ccp_alpha=0.01, max_depth=13, max_features=None, min_impurity_decrease=0.01, min_samples_leaf=3, n_estimators=800; neg_mean_absolute_error: (train=-4.819, test=-8.465) r2: (train=0.785, test=0.352) total time=   1.4s
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         1.154644      0.287630         0.073428        0.025790
# 1         0.972197      0.005836         0.059511        0.005111
# 2         0.966563      0.008175         0.060540        0.003830
# 3         0.984688      0.003769         0.061053        0.004493
# 4         0.980861      0.022090         0.060041        0.009692
# ..             ...           ...              ...             ...
# 175       1.399724      0.014085         0.079892        0.026712
# 176       1.333987      0.012213         0.062394        0.005301
# 177       1.505966      0.015597         0.066457        0.012242
# 178       1.379011      0.023050         0.062076        0.006155
# 179       1.319558      0.009238         0.059850        0.006929
#
#     param_bootstrap param_ccp_alpha param_max_depth param_max_features  \
# 0              True               0               7               sqrt
# 1              True               0               7               sqrt
# 2              True               0               7               sqrt
# 3              True               0               7               sqrt
# 4              True               0               7               sqrt
# ..              ...             ...             ...                ...
# 175            True            0.01              13               None
# 176            True            0.01              13               None
# 177            True            0.01              13               None
# 178            True            0.01              13               None
# 179            True            0.01              13               None
#
#     param_min_impurity_decrease param_min_samples_leaf  ...  \
# 0                             0                      1  ...
# 1                             0                      2  ...
# 2                             0                      3  ...
# 3                          0.01                      1  ...
# 4                          0.01                      2  ...
# ..                          ...                    ...  ...
# 175                           0                      2  ...
# 176                           0                      3  ...
# 177                        0.01                      1  ...
# 178                        0.01                      2  ...
# 179                        0.01                      3  ...
#
#     split2_train_neg_mean_absolute_error split3_train_neg_mean_absolute_error  \
# 0                              -6.183200                            -6.042558
# 1                              -7.228137                            -7.071794
# 2                              -7.836467                            -7.828029
# 3                              -6.242402                            -6.062686
# 4                              -7.289568                            -7.053221
# ..                                   ...                                  ...
# 175                            -3.932439                            -3.767194
# 176                            -4.843048                            -4.739627
# 177                            -2.942586                            -2.768129
# 178                            -3.939877                            -3.735206
# 179                            -4.885580                            -4.766369
#
#      split4_train_neg_mean_absolute_error  \
# 0                               -6.157620
# 1                               -7.141830
# 2                               -7.868365
# 3                               -6.221373
# 4                               -7.223797
# ..                                    ...
# 175                             -3.720289
# 176                             -4.665383
# 177                             -2.716496
# 178                             -3.715736
# 179                             -4.656270
#
#      split5_train_neg_mean_absolute_error  \
# 0                               -5.950529
# 1                               -6.898532
# 2                               -7.574981
# 3                               -5.953372
# 4                               -7.002000
# ..                                    ...
# 175                             -3.824013
# 176                             -4.819163
# 177                             -2.853202
# 178                             -3.849616
# 179                             -4.812373
#
#      split6_train_neg_mean_absolute_error  \
# 0                               -6.231833
# 1                               -7.288811
# 2                               -7.910740
# 3                               -6.317921
# 4                               -7.387667
# ..                                    ...
# 175                             -3.968904
# 176                             -4.848907
# 177                             -2.940334
# 178                             -3.977553
# 179                             -4.841020
#
#      split7_train_neg_mean_absolute_error  \
# 0                               -5.617829
# 1                               -6.573950
# 2                               -7.288757
# 3                               -5.728897
# 4                               -6.638682
# ..                                    ...
# 175                             -3.648859
# 176                             -4.430678
# 177                             -2.673147
# 178                             -3.625624
# 179                             -4.399815
#
#      split8_train_neg_mean_absolute_error  \
# 0                               -5.978490
# 1                               -7.038154
# 2                               -7.682122
# 3                               -6.134342
# 4                               -7.036718
# ..                                    ...
# 175                             -3.744134
# 176                             -4.647842
# 177                             -2.796975
# 178                             -3.799895
# 179                             -4.618334
#
#      split9_train_neg_mean_absolute_error  mean_train_neg_mean_absolute_error  \
# 0                               -5.879167                           -5.982313
# 1                               -7.043860                           -7.027310
# 2                               -7.706449                           -7.688927
# 3                               -5.897574                           -6.042323
# 4                               -7.004420                           -7.064080
# ..                                    ...                                 ...
# 175                             -3.886977                           -3.791974
# 176                             -4.788142                           -4.701335
# 177                             -2.940304                           -2.824783
# 178                             -3.882206                           -3.793783
# 179                             -4.819118                           -4.707215
#
#      std_train_neg_mean_absolute_error
# 0                             0.176148
# 1                             0.191618
# 2                             0.177829
# 3                             0.180594
# 4                             0.200040
# ..                                 ...
# 175                           0.112994
# 176                           0.137489
# 177                           0.095194
# 178                           0.128997
# 179                           0.149979
#
# [180 rows x 62 columns]
# {'bootstrap': True, 'ccp_alpha': 0, 'max_depth': 13, 'max_features': 'sqrt', 'min_impurity_decrease': 0, 'min_samples_leaf': 1, 'n_estimators': 800}

# %%
cv_results_ = pd.read_csv('/content/grid_search_me.csv')

# %%
### THIS IS NOT NECESSARY, JUST A SANITY CHECK WHICH CONFIRMS THE NUMBERS FROM THE .csv ############

from sklearn import model_selection
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold
from statistics import mean

# Create the parameter grid based on the results of random search
chosen_index = 332 #grid_search_me.csv
print(cv_results_['params'][chosen_index])
tv_rf = RandomForestRegressor(
    bootstrap = cv_results_['param_bootstrap'][chosen_index],
    n_estimators= cv_results_['param_n_estimators'][chosen_index],
    max_depth = cv_results_['param_max_depth'][chosen_index],
    max_features = cv_results_['param_max_features'][chosen_index],
    min_impurity_decrease = cv_results_['param_min_impurity_decrease'][chosen_index],
    min_samples_leaf = cv_results_['param_min_samples_leaf'][chosen_index],
    ccp_alpha = cv_results_['param_ccp_alpha'][chosen_index]
 )

# evaluate the model
cv = StratifiedKFold(n_splits=10, shuffle = True, random_state=42)
mae_v = cross_val_score(tv_rf, X_TV, Y_TV, scoring='neg_mean_absolute_error', cv=10, n_jobs=1)

# report performance
print('MAE:', (mean(mae_v)*(-1), "Standard deviation: ", np.std(mae_v)))

r2_v = cross_val_score(tv_rf, X_TV, Y_TV, scoring='r2', cv=10, n_jobs=1)
print('R2', (mean(r2_v), "Standard deviation: ", np.std(r2_v)))
# Out:
# {'n_estimators': 1000, 'min_samples_leaf': 2, 'min_impurity_decrease': 0.01, 'max_features': 'sqrt', 'max_depth': 12, 'ccp_alpha': 0.01, 'bootstrap': True}
# MAE: (15.024532211542633, 'Standard deviation: ', 3.5740730319793164)
# R2 (0.6278624292661158, 'Standard deviation: ', 0.13748752660414593)

# %% [markdown]
# Read Train + Validation results directly from grid_search

# %%
chosen_index = 332 #grid_search_me.csv

r2_v = []
mae_v = []
r2_tr = []
mae_tr = []

for i in range (10):
  v_r2 = "split"+str(i)+"_test_r2"  
  v_mae = "split"+str(i)+"_test_neg_mean_absolute_error"
  r2_v.append(cv_results_[v_r2][chosen_index])
  mae_v.append(cv_results_[v_mae][chosen_index]*(-1))

  tr_r2 = "split"+str(i)+"_train_r2"  
  tr_mae = "split"+str(i)+"_train_neg_mean_absolute_error"
  r2_tr.append(cv_results_[tr_r2][chosen_index])
  mae_tr.append(cv_results_[tr_mae][chosen_index]*(-1))

print("Validation r2 score: ", round(cv_results_['mean_test_r2'][chosen_index],2), "\n Standard deviation: ", round(cv_results_['std_test_r2'][chosen_index],2) )
print("Train r2 score: ", round(cv_results_['mean_train_r2'][chosen_index],2),"\n Standard deviation: ", round(cv_results_['std_train_r2'][chosen_index],2))
print("Validation MAE score: ", round(cv_results_['mean_test_neg_mean_absolute_error'][chosen_index],2), "\n Standard deviation: ", round(cv_results_['std_test_neg_mean_absolute_error'][chosen_index],2) )
print("Train MAE score: ", round(cv_results_['mean_train_neg_mean_absolute_error'][chosen_index],2),"\n Standard deviation: ", round(cv_results_['std_train_neg_mean_absolute_error'][chosen_index],2))
metrics_TV = pd.DataFrame(list(zip(r2_v,mae_v,r2_tr,mae_tr)), columns =['r2_validation', 'MAE_validation', 'r2_train', 'MAE_train',])


spacing = 0.5
f = plt.figure(figsize=(14,8))
gs = f.add_gridspec(2, 2)
gs.update(wspace = spacing, hspace = spacing)


with sns.axes_style("whitegrid", {"grid.color": ".9"}):
    ax = f.add_subplot(gs[0, 0])
    sns.boxplot(data=metrics_TV, x="r2_validation", color = "goldenrod", boxprops=dict(alpha=.5)).set(
    xlabel='R2 score results on validation set')
    plt.xlim(0.1,0.9)

with sns.axes_style("whitegrid", {"grid.color": ".9"}):
    ax = f.add_subplot(gs[0, 1])
    sns.boxplot(data=metrics_TV, x="r2_train", color = "goldenrod", boxprops=dict(alpha=.5)).set(
    xlabel='R2 score results on train set')
    plt.xlim(0.8,0.85)

with sns.axes_style("whitegrid", {"grid.color": ".9"}):
    ax = f.add_subplot(gs[1, 0])
    sns.boxplot(data=metrics_TV, x="MAE_validation", color = "goldenrod", boxprops=dict(alpha=.5)).set(
    xlabel='MAE score results on validation set')
    plt.xlim(6,22)

with sns.axes_style("whitegrid", {"grid.color": ".9"}):
    ax = f.add_subplot(gs[1, 1])
    sns.boxplot(data=metrics_TV, x="MAE_train", color = "goldenrod", boxprops=dict(alpha=.5)).set(
    xlabel='MAE score results on train set')
    plt.xlim(10,12)
f.savefig('metal_rf.png')
# Out:
# Validation r2 score:  0.63
#  Standard deviation:  0.14
# Train r2 score:  0.82
#  Standard deviation:  0.01
# Validation MAE score:  -14.94
#  Standard deviation:  3.52
# Train MAE score:  -10.64
#  Standard deviation:  0.39

# %% [markdown]
# Hyperparameters applied to (T) set

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

r2=[]
MAE=[]

t_rf = RandomForestRegressor(
    bootstrap = cv_results_['param_bootstrap'][chosen_index],
    n_estimators= cv_results_['param_n_estimators'][chosen_index],
    max_depth = cv_results_['param_max_depth'][chosen_index],
    max_features = cv_results_['param_max_features'][chosen_index],
    min_impurity_decrease = cv_results_['param_min_impurity_decrease'][chosen_index],
    min_samples_leaf = cv_results_['param_min_samples_leaf'][chosen_index],
    ccp_alpha = cv_results_['param_ccp_alpha'][chosen_index]
 )

t_rf.fit(X_TV, Y_TV)

# Get Y predicted
predictions=t_rf.predict(X_T)

# Print out the mean absolute error (mae)
MAE = round(mean_absolute_error(Y_T, predictions),2)
print('Mean Absolute Error:', MAE)

# Print out R2
print('R2:', round(r2_score(Y_T, predictions),2))
# Out:
# Mean Absolute Error: 13.51
# R2: 0.71

# %% [markdown]
# Fitted vs Actual plot (Test set)

# %%
# Visualising the Random Forest Regression results

limit = max(Y_T)
predictions = t_rf.predict(X_T)
mae = np.round(abs(Y_T - predictions))
d = {'Metal: label [t]': Y_T, 'Metal: prediction [t]': predictions, 'mae': mae}
plot = pd.DataFrame(data = d)
# plot absolute settings
sns.set(rc={'figure.figsize':(11.7,8.27)},font_scale=1.5)
sns.set_style("whitegrid", {"grid.color": ".9"})

points = plt.scatter(d["Metal: label [t]"], d["Metal: prediction [t]"], s=50, c=d["mae"], cmap="crest")
plt.colorbar(points)
plt.xlim(0, limit)
plt.ylim(0, limit)

sns.regplot(
    x="Metal: label [t]", y="Metal: prediction [t]", data=plot, scatter = False, color='g')

# %% [markdown]
# Absolute error in the test set plot

# %%
# Visualising the Random Forest Regression results
n = X_T.shape[0]

sns.set_style("whitegrid", {"grid.color": ".9"})
numbers = np.array(list(range(0,int(n),+1)))

value = np.round(abs(Y_T - predictions))
d = {'Absolute error': value, 'dataset': numbers}
plot = pd.DataFrame(data = d)

sns.displot(data = plot, x="dataset", y="Absolute error", height=7,
    aspect=1, binwidth=(5, 5), cmap="YlOrBr")

sns.lineplot(data = plot, x="dataset", y=MAE, color = 'chocolate')

# %% [markdown]
# Feature importance

# %%
pip install shap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting shap
#   Downloading shap-0.41.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (569 kB)
#      |████████████████████████████████| 569 kB 5.1 MB/s
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.7/dist-packages (from shap) (4.64.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from shap) (1.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from shap) (1.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from shap) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from shap) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from shap) (1.7.3)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.7/dist-packages (from shap) (21.3)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from shap) (0.56.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>20.9->shap) (3.0.9)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->shap) (0.39.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->shap) (4.12.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->shap) (57.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->shap) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->shap) (3.8.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (3.1.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.41.0 slicer-0.0.7

# %%
import shap
from scipy.special import softmax
from sklearn.feature_selection import SelectFwe, chi2

def print_feature_importances_random_forest(random_forest_model):
    
    '''
    Prints the feature importances of a Random Forest model in an ordered way.
    random_forest_model -> The sklearn.ensemble.RandomForestRegressor or RandomForestClassifier trained model
    '''
    
    # Fetch the feature importances and feature names
    importances = rf.feature_importances_
    features = headers
    
    # Organize them in a dictionary
    feature_importances = {fea: imp for imp, fea in zip(importances, features)}
    
    # Sorts the dictionary
    feature_importances = {k: v for k, v in sorted(feature_importances.items(), key=lambda item: item[1], reverse = True)}
    
    # Prints the feature importances
    for k, v in feature_importances.items():
        print(f"{k} -> {v:.4f}")

def print_feature_importances_shap_values(shap_values, features):
    
    '''
    Prints the feature importances based on SHAP values in an ordered way
    shap_values -> The SHAP values calculated from a shap.Explainer object
    features -> The name of the features, on the order presented to the explainer
    '''

    # Calculates the feature importance (mean absolute shap value) for each feature
    importances = []
    for i in range(shap_values.values.shape[1]):
        importances.append(np.mean(np.abs(shap_values.values[:, i])))
        
    # Calculates the normalized version
    importances_norm = softmax(importances)

    # Organize the importances and columns in a dictionary
    feature_importances = {fea: imp for imp, fea in zip(importances, features)}
    feature_importances_norm = {fea: imp for imp, fea in zip(importances_norm, features)}

    # Sorts the dictionary
    feature_importances = {k: v for k, v in sorted(feature_importances.items(), key=lambda item: item[1], reverse = True)}
    feature_importances_norm= {k: v for k, v in sorted(feature_importances_norm.items(), key=lambda item: item[1], reverse = True)}

    # Prints the feature importances
    for k, v in feature_importances.items():
        print(f"{k} -> {v:.4f} (softmax = {feature_importances_norm[k]:.4f})")

# %%
import shap
# Fits the explainer
explainer = shap.Explainer(t_rf,feature_names= headers)
# Calculates the SHAP values - It takes some time
shap_values = explainer(X)

# %%
shap.summary_plot(shap_values, feature_names = headers)

import matplotlib.pyplot as pl
fig = pl.gcf()
fig.savefig('me_rf_imp.png')
